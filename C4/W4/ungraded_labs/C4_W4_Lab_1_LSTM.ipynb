# %% [markdown]
# # Ungraded Lab: Using Convolutions with LSTMs
#
# Welcome to the final week of this course! In this lab, you will build upon the RNN models you built last week and append a convolution layer to it. As you saw in previous courses, convolution filters can also capture features from sequences so it's good to try them out when exploring model architectures. Let's begin!

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2025-02-26 10:54:15.136477: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-02-26 10:54:15.269122: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-02-26 10:54:15.270021: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-26 10:54:17.119628: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Utilities
#
# You will be plotting the MAE and loss later so the `plot_series()` is extended to have more labelling functionality. The utilities for generating the synthetic data is the same as the previous labs.

# %%
def plot_series(x, y, format="-", start=0, end=None, 
                title=None, xlabel=None, ylabel=None, legend=None ):
    """
    Visualizes time series data

    Args:
      x (array of int) - contains values for the x-axis
      y (array of int or tuple of arrays) - contains the values for the y-axis
      format (string) - line style when plotting the graph
      start (int) - first time step to plot
      end (int) - last time step to plot
      title (string) - title of the plot
      xlabel (string) - label for the x-axis
      ylabel (string) - label for the y-axis
      legend (list of strings) - legend for the plot
    """

    # Setup dimensions of the graph figure
    plt.figure(figsize=(10, 6))
    
    # Check if there are more than two series to plot
    if type(y) is tuple:

      # Loop over the y elements
      for y_curr in y:

        # Plot the x and current y values
        plt.plot(x[start:end], y_curr[start:end], format)

    else:
      # Plot the x and y values
      plt.plot(x[start:end], y[start:end], format)

    # Label the x-axis
    plt.xlabel(xlabel)

    # Label the y-axis
    plt.ylabel(ylabel)

    # Set the legend
    if legend:
      plt.legend(legend)

    # Set the title
    plt.title(title)

    # Overlay a grid on the graph
    plt.grid(True)

    # Draw the graph on screen
    plt.show()

def trend(time, slope=0):
    """
    Generates synthetic data that follows a straight line given a slope value.

    Args:
      time (array of int) - contains the time steps
      slope (float) - determines the direction and steepness of the line

    Returns:
      series (array of float) - measurements that follow a straight line
    """

    # Compute the linear series given the slope
    series = slope * time

    return series

def seasonal_pattern(season_time):
    """
    Just an arbitrary pattern, you can change it if you wish
    
    Args:
      season_time (array of float) - contains the measurements per time step

    Returns:
      data_pattern (array of float) -  contains revised measurement values according 
                                  to the defined pattern
    """

    # Generate the values using an arbitrary pattern
    data_pattern = np.where(season_time < 0.4,
                    np.cos(season_time * 2 * np.pi),
                    1 / np.exp(3 * season_time))
    
    return data_pattern

def seasonality(time, period, amplitude=1, phase=0):
    """
    Repeats the same pattern at each period

    Args:
      time (array of int) - contains the time steps
      period (int) - number of time steps before the pattern repeats
      amplitude (int) - peak measured value in a period
      phase (int) - number of time steps to shift the measured values

    Returns:
      data_pattern (array of float) - seasonal data scaled by the defined amplitude
    """
    
    # Define the measured values per period
    season_time = ((time + phase) % period) / period

    # Generates the seasonal data scaled by the defined amplitude
    data_pattern = amplitude * seasonal_pattern(season_time)

    return data_pattern

def noise(time, noise_level=1, seed=None):
    """Generates a normally distributed noisy signal

    Args:
      time (array of int) - contains the time steps
      noise_level (float) - scaling factor for the generated signal
      seed (int) - number generator seed for repeatability

    Returns:
      noise (array of float) - the noisy signal
    """

    # Initialize the random number generator
    rnd = np.random.RandomState(seed)

    # Generate a random number for each time step and scale by the noise level
    noise = rnd.randn(len(time)) * noise_level
    
    return noise

# %% [markdown]
# ## Generate the Synthetic Data

# %%
# Parameters
time = np.arange(4 * 365 + 1, dtype="float32")
baseline = 10
amplitude = 40
slope = 0.05
noise_level = 5

# Create the series
series = baseline + trend(time, slope) + \
    seasonality(time, period=365, amplitude=amplitude)

# Update with noise
series += noise(time, noise_level, seed=42)

# Plot the results
plot_series(time, series, xlabel='Time', ylabel='Value')

# %% [markdown]
# ## Split the Dataset

# %%
# Define the split time
split_time = 1000

# Get the train set 
time_train = time[:split_time]
x_train = series[:split_time]

# Get the validation set
time_valid = time[split_time:]
x_valid = series[split_time:]

# %% [markdown]
# ## Prepare Features and Labels
#
# As mentioned in the lectures, you can experiment with different batch sizing here and see how it affects your results.

# %%
# Parameters
window_size = 20
batch_size = 16
shuffle_buffer_size = 1000

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer,
                     labels_size=1):
    """Generates dataset windows

    Args:
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the feature
      batch_size (int) - the batch size
      shuffle_buffer(int) - buffer size to use for the shuffle method

    Returns:
      dataset (TF Dataset) - TF Dataset containing time windows
    """

    # Add an axis for the feature dimension of RNN layers
    series = tf.expand_dims(series, axis=-1) # NOTICE aditional axis!

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)
    
    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)
    
    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))

    # Create tuples with features and labels 
    dataset = dataset.map(lambda window: (window[:-labels_size],
                                          window[-labels_size]))

    # Shuffle the windows
    dataset = dataset.shuffle(shuffle_buffer)
    
    # Create batches of windows
    dataset = dataset.batch(batch_size)
    
    # Optimize the dataset for training
    dataset = dataset.cache().prefetch(1)
    
    return dataset

# %%
# Generate the dataset windows
train_set = windowed_dataset(
    x_train, window_size, batch_size, shuffle_buffer_size)

# %% [markdown]
# ## Build the Model
#
# Here is the model architecture you will be using. It is very similar to the last RNN you built but with the [Conv1D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv1D) layer at the input. One important [argument](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv1D#args) here is the `padding`. For time series data, it is good practice to not let computations for a particular time step to be affected by values into the future. Here is one way of looking at it:
#
# * Let's say you have a small time series window with these values: `[1, 2, 3, 4, 5]`. This means the value `1` is at `t=0`, `2` is at `t=1`, etc.
# * If you have a 1D kernel of size `3`, then the first convolution will be for the values at `[1, 2, 3]` which are values for `t=0` to `t=2`.
# * When you pass this to the first timestep of the `LSTM` after the convolution, it means that the value at `t=0` of the LSTM depends on `t=1` and `t=2` which are values into the future.
# * For time series data, you want computations to only rely on current and previous time steps.
# * One way to do that is to pad the array depending on the kernel size and stride. For a kernel size of 3 and stride of 1, the window can be padded as such: `[0, 0, 1, 2, 3, 4, 5]`. `1` is still at `t=0` and two zeroes are prepended to simulate values in the past.
# * This way, the first stride will be at `[0, 0, 1]` and this does not contain any future values when it is passed on to subsequent layers.
#
# The `Conv1D` layer does this kind of padding by setting `padding=causal` and you'll see that below.

# %%
# Reset states generated by Keras
tf.keras.backend.clear_session()

# Build the model
model = tf.keras.models.Sequential([
    tf.keras.Input(shape=(window_size,1)),
    tf.keras.layers.Conv1D(filters=64, kernel_size=3,
                      strides=1, padding="causal",
                      activation="relu"),
    tf.keras.layers.LSTM(64, return_sequences=True),
    tf.keras.layers.LSTM(64),
    tf.keras.layers.Dense(1),
    tf.keras.layers.Lambda(lambda x: x * 400)
])

# Print the model summary
model.summary()
# Out:
# 2025-02-26 10:57:27.599041: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 10:57:27.601196: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 10:57:27.603218: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 20, 64)            256
#
#  lstm (LSTM)                 (None, 20, 64)            33024
#
#  lstm_1 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 1)                 65
#
#  lambda (Lambda)             (None, 1)                 0
#
# =================================================================
# Total params: 66,369
# Trainable params: 66,369
# Non-trainable params: 0
# _________________________________________________________________
# 2025-02-26 10:57:28.187273: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 10:57:28.191125: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 10:57:28.195397: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %% [markdown]
# ## Tune the Learning Rate
#
# In the previous labs, you are using different models for tuning and training. That is a valid approach but you can also use the same model for both. Before tuning, you can use the [`get_weights()`](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Layer#get_weights) method so you can reset it later.

# %%
# Get initial weights
init_weights = model.get_weights()

# %% [markdown]
# After that, you can tune the model as usual.

# %%
# Set the learning rate scheduler
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))

# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD(momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer)

# Train the model
history = model.fit(train_set, epochs=100, callbacks=[lr_schedule])
# Out:
# Epoch 1/100
# 2025-02-26 11:00:54.449124: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [1000,1]
# 	 [[{{node Placeholder/_0}}]]
# 2025-02-26 11:00:54.450210: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [1000,1]
# 	 [[{{node Placeholder/_0}}]]
# 2025-02-26 11:00:54.936950: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 11:00:54.941453: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 11:00:54.945891: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 11:00:55.318158: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 11:00:55.322401: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 11:00:55.326101: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 11:00:56.913868: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 11:00:56.916999: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 11:00:56.918628: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 11:00:57.265389: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 11:00:57.268999: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 11:00:57.271896: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 62/62 [==============================] - 8s 41ms/step - loss: 184.0090 - lr: 1.0000e-08
# Epoch 2/100
# 62/62 [==============================] - 2s 38ms/step - loss: 49.8127 - lr: 1.1220e-08
# Epoch 3/100
# 62/62 [==============================] - 2s 34ms/step - loss: 17.3400 - lr: 1.2589e-08
# Epoch 4/100
# 62/62 [==============================] - 2s 34ms/step - loss: 14.6445 - lr: 1.4125e-08
# Epoch 5/100
# 62/62 [==============================] - 2s 32ms/step - loss: 13.2400 - lr: 1.5849e-08
# Epoch 6/100
# 62/62 [==============================] - 2s 35ms/step - loss: 12.5782 - lr: 1.7783e-08
# Epoch 7/100
# 62/62 [==============================] - 2s 33ms/step - loss: 12.1627 - lr: 1.9953e-08
# Epoch 8/100
# 62/62 [==============================] - 2s 33ms/step - loss: 11.7750 - lr: 2.2387e-08
# Epoch 9/100
# 62/62 [==============================] - 2s 31ms/step - loss: 11.3996 - lr: 2.5119e-08
# Epoch 10/100
# 62/62 [==============================] - 2s 33ms/step - loss: 11.0743 - lr: 2.8184e-08
# Epoch 11/100
# 62/62 [==============================] - 2s 34ms/step - loss: 10.7796 - lr: 3.1623e-08
# Epoch 12/100
# 62/62 [==============================] - 2s 33ms/step - loss: 10.4897 - lr: 3.5481e-08
# Epoch 13/100
# 62/62 [==============================] - 2s 34ms/step - loss: 10.1992 - lr: 3.9811e-08
# Epoch 14/100
# 62/62 [==============================] - 2s 34ms/step - loss: 9.9041 - lr: 4.4668e-08
# Epoch 15/100
# 62/62 [==============================] - 2s 36ms/step - loss: 9.6131 - lr: 5.0119e-08
# Epoch 16/100
# 62/62 [==============================] - 2s 33ms/step - loss: 9.3261 - lr: 5.6234e-08
# Epoch 17/100
# 62/62 [==============================] - 2s 35ms/step - loss: 8.9878 - lr: 6.3096e-08
# Epoch 18/100
# 62/62 [==============================] - 2s 32ms/step - loss: 8.5039 - lr: 7.0795e-08
# Epoch 19/100
# 62/62 [==============================] - 2s 33ms/step - loss: 8.0862 - lr: 7.9433e-08
# Epoch 20/100
# 62/62 [==============================] - 2s 31ms/step - loss: 7.6728 - lr: 8.9125e-08
# Epoch 21/100
# 62/62 [==============================] - 2s 38ms/step - loss: 7.2771 - lr: 1.0000e-07
# Epoch 22/100
# 62/62 [==============================] - 2s 31ms/step - loss: 6.9441 - lr: 1.1220e-07
# Epoch 23/100
# 62/62 [==============================] - 2s 33ms/step - loss: 6.5737 - lr: 1.2589e-07
# Epoch 24/100
# 62/62 [==============================] - 2s 32ms/step - loss: 6.0742 - lr: 1.4125e-07
# Epoch 25/100
# 62/62 [==============================] - 2s 32ms/step - loss: 5.7262 - lr: 1.5849e-07
# Epoch 26/100
# 62/62 [==============================] - 2s 34ms/step - loss: 5.5746 - lr: 1.7783e-07
# Epoch 27/100
# 62/62 [==============================] - 2s 32ms/step - loss: 5.5759 - lr: 1.9953e-07
# Epoch 28/100
# 62/62 [==============================] - 2s 32ms/step - loss: 5.5371 - lr: 2.2387e-07
# Epoch 29/100
# 62/62 [==============================] - 2s 31ms/step - loss: 5.5352 - lr: 2.5119e-07
# Epoch 30/100
# 62/62 [==============================] - 2s 35ms/step - loss: 5.5426 - lr: 2.8184e-07
# Epoch 31/100
# 62/62 [==============================] - 2s 35ms/step - loss: 5.5889 - lr: 3.1623e-07
# Epoch 32/100
# 62/62 [==============================] - 2s 33ms/step - loss: 5.8291 - lr: 3.5481e-07
# Epoch 33/100
# 62/62 [==============================] - 2s 32ms/step - loss: 5.6060 - lr: 3.9811e-07
# Epoch 34/100
# 62/62 [==============================] - 2s 33ms/step - loss: 5.5519 - lr: 4.4668e-07
# Epoch 35/100
# 62/62 [==============================] - 2s 32ms/step - loss: 6.0035 - lr: 5.0119e-07
# Epoch 36/100
# 62/62 [==============================] - 2s 33ms/step - loss: 5.4766 - lr: 5.6234e-07
# Epoch 37/100
# 62/62 [==============================] - 2s 31ms/step - loss: 5.4683 - lr: 6.3096e-07
# Epoch 38/100
# 62/62 [==============================] - 2s 33ms/step - loss: 6.0160 - lr: 7.0795e-07
# Epoch 39/100
# 62/62 [==============================] - 2s 30ms/step - loss: 5.6166 - lr: 7.9433e-07
# Epoch 40/100
# 62/62 [==============================] - 2s 34ms/step - loss: 5.7034 - lr: 8.9125e-07
# Epoch 41/100
# 62/62 [==============================] - 2s 35ms/step - loss: 7.0309 - lr: 1.0000e-06
# Epoch 42/100
# 62/62 [==============================] - 2s 33ms/step - loss: 6.7849 - lr: 1.1220e-06
# Epoch 43/100
# 62/62 [==============================] - 2s 32ms/step - loss: 6.8693 - lr: 1.2589e-06
# Epoch 44/100
# 62/62 [==============================] - 2s 34ms/step - loss: 5.9421 - lr: 1.4125e-06
# Epoch 45/100
# 62/62 [==============================] - 2s 33ms/step - loss: 5.8583 - lr: 1.5849e-06
# Epoch 46/100
# 62/62 [==============================] - 2s 33ms/step - loss: 7.4982 - lr: 1.7783e-06
# Epoch 47/100
# 62/62 [==============================] - 2s 31ms/step - loss: 8.1391 - lr: 1.9953e-06
# Epoch 48/100
# 62/62 [==============================] - 2s 33ms/step - loss: 7.8143 - lr: 2.2387e-06
# Epoch 49/100
# 62/62 [==============================] - 2s 30ms/step - loss: 5.7908 - lr: 2.5119e-06
# Epoch 50/100
# 62/62 [==============================] - 2s 33ms/step - loss: 6.5382 - lr: 2.8184e-06
# Epoch 51/100
# 62/62 [==============================] - 2s 34ms/step - loss: 8.2462 - lr: 3.1623e-06
# Epoch 52/100
# 62/62 [==============================] - 2s 35ms/step - loss: 11.2106 - lr: 3.5481e-06
# Epoch 53/100
# 62/62 [==============================] - 2s 32ms/step - loss: 6.9277 - lr: 3.9811e-06
# Epoch 54/100
# 62/62 [==============================] - 2s 34ms/step - loss: 6.5926 - lr: 4.4668e-06
# Epoch 55/100
# 62/62 [==============================] - 2s 32ms/step - loss: 8.9368 - lr: 5.0119e-06
# Epoch 56/100
# 62/62 [==============================] - 2s 33ms/step - loss: 12.6061 - lr: 5.6234e-06
# Epoch 57/100
# 62/62 [==============================] - 2s 31ms/step - loss: 10.1746 - lr: 6.3096e-06
# Epoch 58/100
# 62/62 [==============================] - 2s 32ms/step - loss: 13.2586 - lr: 7.0795e-06
# Epoch 59/100
# 62/62 [==============================] - 2s 31ms/step - loss: 8.1995 - lr: 7.9433e-06
# Epoch 60/100
# 62/62 [==============================] - 2s 34ms/step - loss: 12.4404 - lr: 8.9125e-06
# Epoch 61/100
# 62/62 [==============================] - 2s 33ms/step - loss: 11.1949 - lr: 1.0000e-05
# Epoch 62/100
# 62/62 [==============================] - 2s 33ms/step - loss: 9.8326 - lr: 1.1220e-05
# Epoch 63/100
# 62/62 [==============================] - 2s 32ms/step - loss: 10.7591 - lr: 1.2589e-05
# Epoch 64/100
# 62/62 [==============================] - 2s 34ms/step - loss: 10.7584 - lr: 1.4125e-05
# Epoch 65/100
# 62/62 [==============================] - 2s 32ms/step - loss: 14.8944 - lr: 1.5849e-05
# Epoch 66/100
# 62/62 [==============================] - 2s 33ms/step - loss: 15.5366 - lr: 1.7783e-05
# Epoch 67/100
# 62/62 [==============================] - 2s 31ms/step - loss: 9.3715 - lr: 1.9953e-05
# Epoch 68/100
# 62/62 [==============================] - 2s 32ms/step - loss: 11.6688 - lr: 2.2387e-05
# Epoch 69/100
# 62/62 [==============================] - 2s 31ms/step - loss: 12.1903 - lr: 2.5119e-05
# Epoch 70/100
# 62/62 [==============================] - 2s 33ms/step - loss: 12.0233 - lr: 2.8184e-05
# Epoch 71/100
# 62/62 [==============================] - 2s 35ms/step - loss: 8.9436 - lr: 3.1623e-05
# Epoch 72/100
# 62/62 [==============================] - 2s 33ms/step - loss: 12.4969 - lr: 3.5481e-05
# Epoch 73/100
# 62/62 [==============================] - 2s 32ms/step - loss: 8.1310 - lr: 3.9811e-05
# Epoch 74/100
# 62/62 [==============================] - 2s 35ms/step - loss: 14.9248 - lr: 4.4668e-05
# Epoch 75/100
# 62/62 [==============================] - 2s 33ms/step - loss: 8.9778 - lr: 5.0119e-05
# Epoch 76/100
# 62/62 [==============================] - 2s 33ms/step - loss: 9.5344 - lr: 5.6234e-05
# Epoch 77/100
# 62/62 [==============================] - 2s 31ms/step - loss: 11.7008 - lr: 6.3096e-05
# Epoch 78/100
# 62/62 [==============================] - 2s 32ms/step - loss: 8.2383 - lr: 7.0795e-05
# Epoch 79/100
# 62/62 [==============================] - 2s 31ms/step - loss: 8.7508 - lr: 7.9433e-05
# Epoch 80/100
# 62/62 [==============================] - 2s 36ms/step - loss: 9.5228 - lr: 8.9125e-05
# Epoch 81/100
# 62/62 [==============================] - 2s 33ms/step - loss: 17.5640 - lr: 1.0000e-04
# Epoch 82/100
# 62/62 [==============================] - 2s 34ms/step - loss: 14.7590 - lr: 1.1220e-04
# Epoch 83/100
# 62/62 [==============================] - 2s 32ms/step - loss: 14.1221 - lr: 1.2589e-04
# Epoch 84/100
# 62/62 [==============================] - 2s 34ms/step - loss: 22.1521 - lr: 1.4125e-04
# Epoch 85/100
# 62/62 [==============================] - 2s 32ms/step - loss: 11.3076 - lr: 1.5849e-04
# Epoch 86/100
# 62/62 [==============================] - 2s 33ms/step - loss: 23.4541 - lr: 1.7783e-04
# Epoch 87/100
# 62/62 [==============================] - 2s 33ms/step - loss: 17.6884 - lr: 1.9953e-04
# Epoch 88/100
# 62/62 [==============================] - 2s 31ms/step - loss: 27.0150 - lr: 2.2387e-04
# Epoch 89/100
# 62/62 [==============================] - 2s 34ms/step - loss: 41.0883 - lr: 2.5119e-04
# Epoch 90/100
# 62/62 [==============================] - 2s 33ms/step - loss: 31.3539 - lr: 2.8184e-04
# Epoch 91/100
# 62/62 [==============================] - 2s 36ms/step - loss: 27.0645 - lr: 3.1623e-04
# Epoch 92/100
# 62/62 [==============================] - 2s 32ms/step - loss: 27.0978 - lr: 3.5481e-04
# Epoch 93/100
# 62/62 [==============================] - 2s 33ms/step - loss: 32.0920 - lr: 3.9811e-04
# Epoch 94/100
# 62/62 [==============================] - 2s 33ms/step - loss: 37.3174 - lr: 4.4668e-04
# Epoch 95/100
# 62/62 [==============================] - 2s 34ms/step - loss: 93.4680 - lr: 5.0119e-04
# Epoch 96/100
# 62/62 [==============================] - 2s 32ms/step - loss: 63.6288 - lr: 5.6234e-04
# Epoch 97/100
# 62/62 [==============================] - 2s 32ms/step - loss: 91.2028 - lr: 6.3096e-04
# Epoch 98/100
# 62/62 [==============================] - 2s 33ms/step - loss: 43.6669 - lr: 7.0795e-04
# Epoch 99/100
# 62/62 [==============================] - 2s 33ms/step - loss: 126.9129 - lr: 7.9433e-04
# Epoch 100/100
# 62/62 [==============================] - 2s 37ms/step - loss: 138.2001 - lr: 8.9125e-04

# %%
# Define the learning rate array
lrs = 1e-8 * (10 ** (np.arange(100) / 20))

# Set the figure size
plt.figure(figsize=(10, 6))

# Set the grid
plt.grid(True)

# Plot the loss in log scale
plt.semilogx(lrs, history.history["loss"])

# Increase the tickmarks size
plt.tick_params('both', length=10, width=1, which='both')

# Set the plot boundaries
plt.axis([1e-8, 1e-3, 0, 50])
# Out:
# (1e-08, 0.001, 0.0, 50.0)

# %% [markdown]
# ## Train the Model
#
# To reset the weights, you can simply call the [`set_weights()`](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Layer#set_weights) and pass in the saved weights from earlier.

# %%
# Reset states generated by Keras
tf.keras.backend.clear_session()

# Reset the weights
model.set_weights(init_weights)

# %% [markdown]
# Then you can set the training parameters and start training.

# %%
# Set the learning rate
learning_rate = 1e-7

# Set the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# %%
# Train the model
history = model.fit(train_set,epochs=500)
# Out:
# Epoch 1/500
# 2025-02-26 11:05:12.933668: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 11:05:12.938324: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 11:05:12.942610: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 11:05:13.333289: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 11:05:13.337291: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 11:05:13.339949: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 11:05:14.918885: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 11:05:14.921526: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 11:05:14.924359: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 11:05:15.572114: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 11:05:15.576223: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 11:05:15.579933: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 62/62 [==============================] - 8s 33ms/step - loss: 59.1708 - mae: 59.6658
# Epoch 2/500
# 62/62 [==============================] - 2s 31ms/step - loss: 12.3015 - mae: 12.7897
# Epoch 3/500
# 62/62 [==============================] - 2s 35ms/step - loss: 10.8934 - mae: 11.3809
# Epoch 4/500
# 62/62 [==============================] - 2s 32ms/step - loss: 9.9334 - mae: 10.4187
# Epoch 5/500
# 62/62 [==============================] - 2s 35ms/step - loss: 9.2672 - mae: 9.7523
# Epoch 6/500
# 62/62 [==============================] - 2s 32ms/step - loss: 8.6994 - mae: 9.1843
# Epoch 7/500
# 62/62 [==============================] - 2s 34ms/step - loss: 8.1631 - mae: 8.6460
# Epoch 8/500
# 62/62 [==============================] - 2s 34ms/step - loss: 7.6599 - mae: 8.1448
# Epoch 9/500
# 62/62 [==============================] - 2s 34ms/step - loss: 7.1837 - mae: 7.6657
# Epoch 10/500
# 62/62 [==============================] - 2s 33ms/step - loss: 6.7431 - mae: 7.2224
# Epoch 11/500
# 62/62 [==============================] - 2s 36ms/step - loss: 6.3541 - mae: 6.8356
# Epoch 12/500
# 62/62 [==============================] - 2s 36ms/step - loss: 6.0382 - mae: 6.5205
# Epoch 13/500
# 62/62 [==============================] - 4s 58ms/step - loss: 5.8071 - mae: 6.2863
# Epoch 14/500
# 62/62 [==============================] - 3s 46ms/step - loss: 5.6625 - mae: 6.1400
# Epoch 15/500
# 62/62 [==============================] - 2s 32ms/step - loss: 5.5683 - mae: 6.0448
# Epoch 16/500
# 62/62 [==============================] - 2s 33ms/step - loss: 5.5135 - mae: 5.9895
# Epoch 17/500
# 62/62 [==============================] - 2s 36ms/step - loss: 5.4722 - mae: 5.9497
# Epoch 18/500
# 62/62 [==============================] - 2s 35ms/step - loss: 5.4295 - mae: 5.9081
# Epoch 19/500
# 62/62 [==============================] - 2s 38ms/step - loss: 5.3861 - mae: 5.8652
# Epoch 20/500
# 62/62 [==============================] - 3s 47ms/step - loss: 5.3449 - mae: 5.8244
# Epoch 21/500
# 62/62 [==============================] - 2s 34ms/step - loss: 5.3067 - mae: 5.7861
# Epoch 22/500
# 62/62 [==============================] - 2s 39ms/step - loss: 5.2718 - mae: 5.7509
# Epoch 23/500
# 62/62 [==============================] - 2s 34ms/step - loss: 5.2406 - mae: 5.7198
# Epoch 24/500
# 62/62 [==============================] - 2s 33ms/step - loss: 5.2123 - mae: 5.6918
# Epoch 25/500
# 62/62 [==============================] - 2s 33ms/step - loss: 5.1869 - mae: 5.6665
# Epoch 26/500
# 62/62 [==============================] - 2s 29ms/step - loss: 5.1628 - mae: 5.6425
# Epoch 27/500
# 62/62 [==============================] - 2s 31ms/step - loss: 5.1404 - mae: 5.6198
# Epoch 28/500
# 62/62 [==============================] - 2s 29ms/step - loss: 5.1207 - mae: 5.5996
# Epoch 29/500
# 62/62 [==============================] - 2s 33ms/step - loss: 5.1043 - mae: 5.5830
# Epoch 30/500
# 62/62 [==============================] - 2s 29ms/step - loss: 5.0882 - mae: 5.5665
# Epoch 31/500
# 62/62 [==============================] - 2s 33ms/step - loss: 5.0717 - mae: 5.5496
# Epoch 32/500
# 62/62 [==============================] - 2s 29ms/step - loss: 5.0548 - mae: 5.5324
# Epoch 33/500
# 62/62 [==============================] - 2s 31ms/step - loss: 5.0376 - mae: 5.5148
# Epoch 34/500
# 62/62 [==============================] - 2s 29ms/step - loss: 5.0216 - mae: 5.4985
# Epoch 35/500
# 62/62 [==============================] - 2s 30ms/step - loss: 5.0068 - mae: 5.4838
# Epoch 36/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.9934 - mae: 5.4706
# Epoch 37/500
# 62/62 [==============================] - 2s 30ms/step - loss: 4.9809 - mae: 5.4579
# Epoch 38/500
# 62/62 [==============================] - 2s 30ms/step - loss: 4.9685 - mae: 5.4454
# Epoch 39/500
# 62/62 [==============================] - 2s 30ms/step - loss: 4.9553 - mae: 5.4321
# Epoch 40/500
# 62/62 [==============================] - 2s 29ms/step - loss: 4.9423 - mae: 5.4190
# Epoch 41/500
# 62/62 [==============================] - 2s 30ms/step - loss: 4.9294 - mae: 5.4064
# Epoch 42/500
# 62/62 [==============================] - 2s 29ms/step - loss: 4.9168 - mae: 5.3940
# Epoch 43/500
# 62/62 [==============================] - 2s 29ms/step - loss: 4.9046 - mae: 5.3820
# Epoch 44/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.8922 - mae: 5.3699
# Epoch 45/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.8800 - mae: 5.3577
# Epoch 46/500
# 62/62 [==============================] - 3s 49ms/step - loss: 4.8676 - mae: 5.3454
# Epoch 47/500
# 62/62 [==============================] - 3s 48ms/step - loss: 4.8558 - mae: 5.3335
# Epoch 48/500
# 62/62 [==============================] - 3s 41ms/step - loss: 4.8443 - mae: 5.3221
# Epoch 49/500
# 62/62 [==============================] - 3s 47ms/step - loss: 4.8335 - mae: 5.3112
# Epoch 50/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.8230 - mae: 5.3007
# Epoch 51/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.8131 - mae: 5.2907
# Epoch 52/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.8034 - mae: 5.2811
# Epoch 53/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.7940 - mae: 5.2717
# Epoch 54/500
# 62/62 [==============================] - 3s 44ms/step - loss: 4.7845 - mae: 5.2622
# Epoch 55/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.7751 - mae: 5.2528
# Epoch 56/500
# 62/62 [==============================] - 3s 48ms/step - loss: 4.7658 - mae: 5.2434
# Epoch 57/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.7566 - mae: 5.2340
# Epoch 58/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.7477 - mae: 5.2250
# Epoch 59/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.7389 - mae: 5.2161
# Epoch 60/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.7302 - mae: 5.2072
# Epoch 61/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.7220 - mae: 5.1988
# Epoch 62/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.7141 - mae: 5.1907
# Epoch 63/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.7065 - mae: 5.1827
# Epoch 64/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.6991 - mae: 5.1749
# Epoch 65/500
# 62/62 [==============================] - 2s 30ms/step - loss: 4.6917 - mae: 5.1671
# Epoch 66/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.6843 - mae: 5.1596
# Epoch 67/500
# 62/62 [==============================] - 3s 43ms/step - loss: 4.6767 - mae: 5.1519
# Epoch 68/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.6693 - mae: 5.1443
# Epoch 69/500
# 62/62 [==============================] - 2s 36ms/step - loss: 4.6623 - mae: 5.1370
# Epoch 70/500
# 62/62 [==============================] - 2s 38ms/step - loss: 4.6558 - mae: 5.1304
# Epoch 71/500
# 62/62 [==============================] - 2s 38ms/step - loss: 4.6492 - mae: 5.1236
# Epoch 72/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.6424 - mae: 5.1167
# Epoch 73/500
# 62/62 [==============================] - 2s 38ms/step - loss: 4.6356 - mae: 5.1099
# Epoch 74/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.6289 - mae: 5.1031
# Epoch 75/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.6222 - mae: 5.0964
# Epoch 76/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.6156 - mae: 5.0898
# Epoch 77/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.6091 - mae: 5.0833
# Epoch 78/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.6027 - mae: 5.0770
# Epoch 79/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.5964 - mae: 5.0708
# Epoch 80/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.5901 - mae: 5.0646
# Epoch 81/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.5838 - mae: 5.0584
# Epoch 82/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.5776 - mae: 5.0522
# Epoch 83/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.5712 - mae: 5.0460
# Epoch 84/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.5652 - mae: 5.0399
# Epoch 85/500
# 62/62 [==============================] - 3s 41ms/step - loss: 4.5593 - mae: 5.0340
# Epoch 86/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.5535 - mae: 5.0282
# Epoch 87/500
# 62/62 [==============================] - 2s 36ms/step - loss: 4.5480 - mae: 5.0230
# Epoch 88/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.5428 - mae: 5.0180
# Epoch 89/500
# 62/62 [==============================] - 2s 36ms/step - loss: 4.5378 - mae: 5.0131
# Epoch 90/500
# 62/62 [==============================] - 2s 38ms/step - loss: 4.5330 - mae: 5.0084
# Epoch 91/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.5284 - mae: 5.0038
# Epoch 92/500
# 62/62 [==============================] - 2s 38ms/step - loss: 4.5239 - mae: 4.9992
# Epoch 93/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.5195 - mae: 4.9949
# Epoch 94/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.5154 - mae: 4.9907
# Epoch 95/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.5115 - mae: 4.9868
# Epoch 96/500
# 62/62 [==============================] - 2s 39ms/step - loss: 4.5076 - mae: 4.9829
# Epoch 97/500
# 62/62 [==============================] - 3s 43ms/step - loss: 4.5040 - mae: 4.9793
# Epoch 98/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.5004 - mae: 4.9758
# Epoch 99/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.4968 - mae: 4.9722
# Epoch 100/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.4933 - mae: 4.9687
# Epoch 101/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.4899 - mae: 4.9655
# Epoch 102/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.4866 - mae: 4.9624
# Epoch 103/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.4837 - mae: 4.9596
# Epoch 104/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.4806 - mae: 4.9566
# Epoch 105/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.4776 - mae: 4.9537
# Epoch 106/500
# 62/62 [==============================] - 2s 36ms/step - loss: 4.4747 - mae: 4.9509
# Epoch 107/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.4718 - mae: 4.9481
# Epoch 108/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.4690 - mae: 4.9453
# Epoch 109/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.4661 - mae: 4.9425
# Epoch 110/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.4634 - mae: 4.9398
# Epoch 111/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.4608 - mae: 4.9372
# Epoch 112/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.4582 - mae: 4.9346
# Epoch 113/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.4557 - mae: 4.9320
# Epoch 114/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.4531 - mae: 4.9294
# Epoch 115/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.4506 - mae: 4.9269
# Epoch 116/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.4481 - mae: 4.9243
# Epoch 117/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.4457 - mae: 4.9216
# Epoch 118/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.4433 - mae: 4.9191
# Epoch 119/500
# 62/62 [==============================] - 2s 36ms/step - loss: 4.4409 - mae: 4.9166
# Epoch 120/500
# 62/62 [==============================] - 2s 39ms/step - loss: 4.4386 - mae: 4.9141
# Epoch 121/500
# 62/62 [==============================] - 2s 36ms/step - loss: 4.4363 - mae: 4.9116
# Epoch 122/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.4341 - mae: 4.9092
# Epoch 123/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.4319 - mae: 4.9068
# Epoch 124/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.4296 - mae: 4.9045
# Epoch 125/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.4274 - mae: 4.9022
# Epoch 126/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.4252 - mae: 4.8998
# Epoch 127/500
# 62/62 [==============================] - 2s 38ms/step - loss: 4.4232 - mae: 4.8977
# Epoch 128/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.4212 - mae: 4.8956
# Epoch 129/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.4192 - mae: 4.8935
# Epoch 130/500
# 62/62 [==============================] - 2s 38ms/step - loss: 4.4173 - mae: 4.8915
# Epoch 131/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.4153 - mae: 4.8895
# Epoch 132/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.4134 - mae: 4.8874
# Epoch 133/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.4113 - mae: 4.8854
# Epoch 134/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.4093 - mae: 4.8836
# Epoch 135/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.4072 - mae: 4.8816
# Epoch 136/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.4051 - mae: 4.8795
# Epoch 137/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.4029 - mae: 4.8774
# Epoch 138/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.4008 - mae: 4.8754
# Epoch 139/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.3983 - mae: 4.8730
# Epoch 140/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.3961 - mae: 4.8709
# Epoch 141/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.3935 - mae: 4.8683
# Epoch 142/500
# 62/62 [==============================] - 2s 30ms/step - loss: 4.3910 - mae: 4.8658
# Epoch 143/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.3888 - mae: 4.8635
# Epoch 144/500
# 62/62 [==============================] - 2s 30ms/step - loss: 4.3867 - mae: 4.8614
# Epoch 145/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.3845 - mae: 4.8592
# Epoch 146/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.3824 - mae: 4.8571
# Epoch 147/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.3801 - mae: 4.8547
# Epoch 148/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.3777 - mae: 4.8523
# Epoch 149/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.3755 - mae: 4.8500
# Epoch 150/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.3732 - mae: 4.8478
# Epoch 151/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.3711 - mae: 4.8456
# Epoch 152/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.3690 - mae: 4.8435
# Epoch 153/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.3668 - mae: 4.8413
# Epoch 154/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.3650 - mae: 4.8395
# Epoch 155/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.3630 - mae: 4.8375
# Epoch 156/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.3611 - mae: 4.8356
# Epoch 157/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.3592 - mae: 4.8337
# Epoch 158/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.3574 - mae: 4.8317
# Epoch 159/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.3557 - mae: 4.8300
# Epoch 160/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.3542 - mae: 4.8285
# Epoch 161/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.3528 - mae: 4.8269
# Epoch 162/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.3514 - mae: 4.8255
# Epoch 163/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.3499 - mae: 4.8239
# Epoch 164/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.3483 - mae: 4.8223
# Epoch 165/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.3466 - mae: 4.8205
# Epoch 166/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.3449 - mae: 4.8187
# Epoch 167/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.3433 - mae: 4.8170
# Epoch 168/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.3418 - mae: 4.8154
# Epoch 169/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.3403 - mae: 4.8138
# Epoch 170/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.3387 - mae: 4.8121
# Epoch 171/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.3372 - mae: 4.8105
# Epoch 172/500
# 62/62 [==============================] - 2s 30ms/step - loss: 4.3356 - mae: 4.8089
# Epoch 173/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.3343 - mae: 4.8074
# Epoch 174/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.3328 - mae: 4.8057
# Epoch 175/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.3313 - mae: 4.8041
# Epoch 176/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.3299 - mae: 4.8026
# Epoch 177/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.3285 - mae: 4.8011
# Epoch 178/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.3270 - mae: 4.7997
# Epoch 179/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.3257 - mae: 4.7983
# Epoch 180/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.3244 - mae: 4.7970
# Epoch 181/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.3231 - mae: 4.7957
# Epoch 182/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.3219 - mae: 4.7944
# Epoch 183/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.3207 - mae: 4.7933
# Epoch 184/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.3194 - mae: 4.7921
# Epoch 185/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.3182 - mae: 4.7910
# Epoch 186/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.3170 - mae: 4.7899
# Epoch 187/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.3158 - mae: 4.7888
# Epoch 188/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.3146 - mae: 4.7877
# Epoch 189/500
# 62/62 [==============================] - 2s 36ms/step - loss: 4.3134 - mae: 4.7865
# Epoch 190/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.3123 - mae: 4.7854
# Epoch 191/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.3113 - mae: 4.7844
# Epoch 192/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.3103 - mae: 4.7833
# Epoch 193/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.3093 - mae: 4.7823
# Epoch 194/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.3083 - mae: 4.7813
# Epoch 195/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.3074 - mae: 4.7804
# Epoch 196/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.3064 - mae: 4.7795
# Epoch 197/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.3054 - mae: 4.7785
# Epoch 198/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.3045 - mae: 4.7776
# Epoch 199/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.3035 - mae: 4.7766
# Epoch 200/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.3025 - mae: 4.7756
# Epoch 201/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.3016 - mae: 4.7747
# Epoch 202/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.3006 - mae: 4.7737
# Epoch 203/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2996 - mae: 4.7727
# Epoch 204/500
# 62/62 [==============================] - 2s 38ms/step - loss: 4.2986 - mae: 4.7716
# Epoch 205/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2976 - mae: 4.7706
# Epoch 206/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2966 - mae: 4.7696
# Epoch 207/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2956 - mae: 4.7686
# Epoch 208/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2947 - mae: 4.7676
# Epoch 209/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.2937 - mae: 4.7666
# Epoch 210/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2927 - mae: 4.7656
# Epoch 211/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2918 - mae: 4.7647
# Epoch 212/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2908 - mae: 4.7636
# Epoch 213/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.2897 - mae: 4.7626
# Epoch 214/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.2887 - mae: 4.7616
# Epoch 215/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.2877 - mae: 4.7605
# Epoch 216/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2867 - mae: 4.7595
# Epoch 217/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2857 - mae: 4.7585
# Epoch 218/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2847 - mae: 4.7575
# Epoch 219/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.2837 - mae: 4.7565
# Epoch 220/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2827 - mae: 4.7555
# Epoch 221/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2817 - mae: 4.7545
# Epoch 222/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2807 - mae: 4.7535
# Epoch 223/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.2797 - mae: 4.7525
# Epoch 224/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2787 - mae: 4.7515
# Epoch 225/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2777 - mae: 4.7505
# Epoch 226/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2768 - mae: 4.7495
# Epoch 227/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.2758 - mae: 4.7486
# Epoch 228/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.2749 - mae: 4.7477
# Epoch 229/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2739 - mae: 4.7467
# Epoch 230/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2730 - mae: 4.7458
# Epoch 231/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2721 - mae: 4.7449
# Epoch 232/500
# 62/62 [==============================] - 2s 30ms/step - loss: 4.2712 - mae: 4.7440
# Epoch 233/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2703 - mae: 4.7430
# Epoch 234/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2694 - mae: 4.7422
# Epoch 235/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2685 - mae: 4.7412
# Epoch 236/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2677 - mae: 4.7404
# Epoch 237/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2668 - mae: 4.7394
# Epoch 238/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2658 - mae: 4.7385
# Epoch 239/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2650 - mae: 4.7376
# Epoch 240/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.2640 - mae: 4.7366
# Epoch 241/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2631 - mae: 4.7356
# Epoch 242/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2621 - mae: 4.7346
# Epoch 243/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.2612 - mae: 4.7337
# Epoch 244/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.2603 - mae: 4.7327
# Epoch 245/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2593 - mae: 4.7317
# Epoch 246/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2584 - mae: 4.7307
# Epoch 247/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2575 - mae: 4.7297
# Epoch 248/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2565 - mae: 4.7287
# Epoch 249/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2556 - mae: 4.7277
# Epoch 250/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2546 - mae: 4.7267
# Epoch 251/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.2537 - mae: 4.7257
# Epoch 252/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2527 - mae: 4.7247
# Epoch 253/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2516 - mae: 4.7236
# Epoch 254/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.2506 - mae: 4.7225
# Epoch 255/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2495 - mae: 4.7213
# Epoch 256/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2484 - mae: 4.7202
# Epoch 257/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2473 - mae: 4.7190
# Epoch 258/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.2462 - mae: 4.7178
# Epoch 259/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2451 - mae: 4.7167
# Epoch 260/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.2439 - mae: 4.7155
# Epoch 261/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2428 - mae: 4.7143
# Epoch 262/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.2417 - mae: 4.7132
# Epoch 263/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2406 - mae: 4.7121
# Epoch 264/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.2395 - mae: 4.7109
# Epoch 265/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2385 - mae: 4.7098
# Epoch 266/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.2374 - mae: 4.7087
# Epoch 267/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2363 - mae: 4.7076
# Epoch 268/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.2353 - mae: 4.7066
# Epoch 269/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2343 - mae: 4.7055
# Epoch 270/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.2333 - mae: 4.7044
# Epoch 271/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.2323 - mae: 4.7034
# Epoch 272/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2313 - mae: 4.7024
# Epoch 273/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.2303 - mae: 4.7014
# Epoch 274/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2293 - mae: 4.7004
# Epoch 275/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2284 - mae: 4.6994
# Epoch 276/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.2275 - mae: 4.6984
# Epoch 277/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2265 - mae: 4.6974
# Epoch 278/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.2256 - mae: 4.6964
# Epoch 279/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2246 - mae: 4.6955
# Epoch 280/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2237 - mae: 4.6945
# Epoch 281/500
# 62/62 [==============================] - 2s 30ms/step - loss: 4.2228 - mae: 4.6935
# Epoch 282/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.2218 - mae: 4.6926
# Epoch 283/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.2209 - mae: 4.6917
# Epoch 284/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.2200 - mae: 4.6908
# Epoch 285/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2192 - mae: 4.6899
# Epoch 286/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2183 - mae: 4.6890
# Epoch 287/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.2174 - mae: 4.6881
# Epoch 288/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2166 - mae: 4.6872
# Epoch 289/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2157 - mae: 4.6863
# Epoch 290/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2147 - mae: 4.6854
# Epoch 291/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2139 - mae: 4.6845
# Epoch 292/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.2130 - mae: 4.6836
# Epoch 293/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.2121 - mae: 4.6827
# Epoch 294/500
# 62/62 [==============================] - 2s 38ms/step - loss: 4.2112 - mae: 4.6818
# Epoch 295/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.2103 - mae: 4.6809
# Epoch 296/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.2094 - mae: 4.6799
# Epoch 297/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.2086 - mae: 4.6791
# Epoch 298/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2078 - mae: 4.6783
# Epoch 299/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.2070 - mae: 4.6775
# Epoch 300/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.2063 - mae: 4.6767
# Epoch 301/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2055 - mae: 4.6760
# Epoch 302/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.2048 - mae: 4.6752
# Epoch 303/500
# 62/62 [==============================] - 2s 36ms/step - loss: 4.2041 - mae: 4.6745
# Epoch 304/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.2033 - mae: 4.6738
# Epoch 305/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.2027 - mae: 4.6731
# Epoch 306/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.2020 - mae: 4.6724
# Epoch 307/500
# 62/62 [==============================] - 3s 41ms/step - loss: 4.2014 - mae: 4.6718
# Epoch 308/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.2008 - mae: 4.6712
# Epoch 309/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.2002 - mae: 4.6706
# Epoch 310/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.1995 - mae: 4.6699
# Epoch 311/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.1988 - mae: 4.6692
# Epoch 312/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.1981 - mae: 4.6685
# Epoch 313/500
# 62/62 [==============================] - 3s 45ms/step - loss: 4.1975 - mae: 4.6679
# Epoch 314/500
# 62/62 [==============================] - 3s 56ms/step - loss: 4.1968 - mae: 4.6672
# Epoch 315/500
# 62/62 [==============================] - 4s 57ms/step - loss: 4.1961 - mae: 4.6665
# Epoch 316/500
# 62/62 [==============================] - 3s 53ms/step - loss: 4.1954 - mae: 4.6658
# Epoch 317/500
# 62/62 [==============================] - 2s 39ms/step - loss: 4.1947 - mae: 4.6651
# Epoch 318/500
# 62/62 [==============================] - 3s 44ms/step - loss: 4.1941 - mae: 4.6645
# Epoch 319/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.1934 - mae: 4.6638
# Epoch 320/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.1927 - mae: 4.6631
# Epoch 321/500
# 62/62 [==============================] - 2s 40ms/step - loss: 4.1920 - mae: 4.6624
# Epoch 322/500
# 62/62 [==============================] - 3s 41ms/step - loss: 4.1913 - mae: 4.6617
# Epoch 323/500
# 62/62 [==============================] - 3s 49ms/step - loss: 4.1906 - mae: 4.6610
# Epoch 324/500
# 62/62 [==============================] - 3s 49ms/step - loss: 4.1900 - mae: 4.6603
# Epoch 325/500
# 62/62 [==============================] - 2s 40ms/step - loss: 4.1893 - mae: 4.6596
# Epoch 326/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.1886 - mae: 4.6589
# Epoch 327/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.1879 - mae: 4.6582
# Epoch 328/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.1872 - mae: 4.6575
# Epoch 329/500
# 62/62 [==============================] - 2s 38ms/step - loss: 4.1865 - mae: 4.6568
# Epoch 330/500
# 62/62 [==============================] - 3s 40ms/step - loss: 4.1859 - mae: 4.6562
# Epoch 331/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.1852 - mae: 4.6554
# Epoch 332/500
# 62/62 [==============================] - 2s 38ms/step - loss: 4.1845 - mae: 4.6548
# Epoch 333/500
# 62/62 [==============================] - 2s 38ms/step - loss: 4.1838 - mae: 4.6541
# Epoch 334/500
# 62/62 [==============================] - 2s 39ms/step - loss: 4.1832 - mae: 4.6535
# Epoch 335/500
# 62/62 [==============================] - 2s 36ms/step - loss: 4.1825 - mae: 4.6528
# Epoch 336/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.1818 - mae: 4.6521
# Epoch 337/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.1811 - mae: 4.6514
# Epoch 338/500
# 62/62 [==============================] - 3s 43ms/step - loss: 4.1805 - mae: 4.6508
# Epoch 339/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.1798 - mae: 4.6501
# Epoch 340/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.1792 - mae: 4.6494
# Epoch 341/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.1784 - mae: 4.6487
# Epoch 342/500
# 62/62 [==============================] - 3s 43ms/step - loss: 4.1778 - mae: 4.6481
# Epoch 343/500
# 62/62 [==============================] - 3s 49ms/step - loss: 4.1771 - mae: 4.6474
# Epoch 344/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.1765 - mae: 4.6467
# Epoch 345/500
# 62/62 [==============================] - 2s 38ms/step - loss: 4.1758 - mae: 4.6461
# Epoch 346/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.1751 - mae: 4.6454
# Epoch 347/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.1745 - mae: 4.6447
# Epoch 348/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.1738 - mae: 4.6440
# Epoch 349/500
# 62/62 [==============================] - 3s 50ms/step - loss: 4.1731 - mae: 4.6434
# Epoch 350/500
# 62/62 [==============================] - 2s 40ms/step - loss: 4.1725 - mae: 4.6427
# Epoch 351/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.1718 - mae: 4.6420
# Epoch 352/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.1712 - mae: 4.6414
# Epoch 353/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.1705 - mae: 4.6407
# Epoch 354/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.1698 - mae: 4.6400
# Epoch 355/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.1691 - mae: 4.6393
# Epoch 356/500
# 62/62 [==============================] - 3s 45ms/step - loss: 4.1685 - mae: 4.6387
# Epoch 357/500
# 62/62 [==============================] - 3s 40ms/step - loss: 4.1678 - mae: 4.6379
# Epoch 358/500
# 62/62 [==============================] - 3s 50ms/step - loss: 4.1672 - mae: 4.6373
# Epoch 359/500
# 62/62 [==============================] - 3s 48ms/step - loss: 4.1665 - mae: 4.6366
# Epoch 360/500
# 62/62 [==============================] - 3s 41ms/step - loss: 4.1658 - mae: 4.6359
# Epoch 361/500
# 62/62 [==============================] - 2s 38ms/step - loss: 4.1652 - mae: 4.6353
# Epoch 362/500
# 62/62 [==============================] - 3s 52ms/step - loss: 4.1645 - mae: 4.6346
# Epoch 363/500
# 62/62 [==============================] - 3s 56ms/step - loss: 4.1639 - mae: 4.6340
# Epoch 364/500
# 62/62 [==============================] - 3s 49ms/step - loss: 4.1632 - mae: 4.6333
# Epoch 365/500
# 62/62 [==============================] - 3s 41ms/step - loss: 4.1625 - mae: 4.6326
# Epoch 366/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.1619 - mae: 4.6319
# Epoch 367/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.1612 - mae: 4.6312
# Epoch 368/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.1605 - mae: 4.6305
# Epoch 369/500
# 62/62 [==============================] - 2s 30ms/step - loss: 4.1598 - mae: 4.6299
# Epoch 370/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.1591 - mae: 4.6291
# Epoch 371/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.1584 - mae: 4.6284
# Epoch 372/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.1577 - mae: 4.6278
# Epoch 373/500
# 62/62 [==============================] - 3s 49ms/step - loss: 4.1570 - mae: 4.6270
# Epoch 374/500
# 62/62 [==============================] - 3s 57ms/step - loss: 4.1563 - mae: 4.6263
# Epoch 375/500
# 62/62 [==============================] - 3s 48ms/step - loss: 4.1556 - mae: 4.6256
# Epoch 376/500
# 62/62 [==============================] - 3s 53ms/step - loss: 4.1549 - mae: 4.6249
# Epoch 377/500
# 62/62 [==============================] - 4s 62ms/step - loss: 4.1542 - mae: 4.6242
# Epoch 378/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.1535 - mae: 4.6235
# Epoch 379/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.1528 - mae: 4.6227
# Epoch 380/500
# 62/62 [==============================] - 2s 39ms/step - loss: 4.1522 - mae: 4.6221
# Epoch 381/500
# 62/62 [==============================] - 2s 36ms/step - loss: 4.1515 - mae: 4.6214
# Epoch 382/500
# 62/62 [==============================] - 2s 36ms/step - loss: 4.1508 - mae: 4.6207
# Epoch 383/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.1502 - mae: 4.6200
# Epoch 384/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.1495 - mae: 4.6194
# Epoch 385/500
# 62/62 [==============================] - 2s 36ms/step - loss: 4.1489 - mae: 4.6188
# Epoch 386/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.1483 - mae: 4.6181
# Epoch 387/500
# 62/62 [==============================] - 2s 36ms/step - loss: 4.1477 - mae: 4.6175
# Epoch 388/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.1471 - mae: 4.6169
# Epoch 389/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.1464 - mae: 4.6162
# Epoch 390/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.1458 - mae: 4.6155
# Epoch 391/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.1452 - mae: 4.6149
# Epoch 392/500
# 62/62 [==============================] - 2s 38ms/step - loss: 4.1445 - mae: 4.6142
# Epoch 393/500
# 62/62 [==============================] - 3s 41ms/step - loss: 4.1439 - mae: 4.6136
# Epoch 394/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.1433 - mae: 4.6130
# Epoch 395/500
# 62/62 [==============================] - 2s 31ms/step - loss: 4.1426 - mae: 4.6123
# Epoch 396/500
# 62/62 [==============================] - 2s 38ms/step - loss: 4.1420 - mae: 4.6116
# Epoch 397/500
# 62/62 [==============================] - 3s 55ms/step - loss: 4.1413 - mae: 4.6110
# Epoch 398/500
# 62/62 [==============================] - 4s 68ms/step - loss: 4.1407 - mae: 4.6103
# Epoch 399/500
# 62/62 [==============================] - 3s 45ms/step - loss: 4.1401 - mae: 4.6097
# Epoch 400/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.1396 - mae: 4.6091
# Epoch 401/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.1389 - mae: 4.6085
# Epoch 402/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.1384 - mae: 4.6079
# Epoch 403/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.1378 - mae: 4.6073
# Epoch 404/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.1372 - mae: 4.6067
# Epoch 405/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.1367 - mae: 4.6061
# Epoch 406/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.1361 - mae: 4.6055
# Epoch 407/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.1355 - mae: 4.6049
# Epoch 408/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.1348 - mae: 4.6042
# Epoch 409/500
# 62/62 [==============================] - 3s 52ms/step - loss: 4.1343 - mae: 4.6036
# Epoch 410/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.1337 - mae: 4.6030
# Epoch 411/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.1331 - mae: 4.6024
# Epoch 412/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.1326 - mae: 4.6019
# Epoch 413/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.1320 - mae: 4.6012
# Epoch 414/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.1315 - mae: 4.6007
# Epoch 415/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.1309 - mae: 4.6001
# Epoch 416/500
# 62/62 [==============================] - 2s 37ms/step - loss: 4.1304 - mae: 4.5996
# Epoch 417/500
# 62/62 [==============================] - 4s 63ms/step - loss: 4.1299 - mae: 4.5990
# Epoch 418/500
# 62/62 [==============================] - 2s 39ms/step - loss: 4.1294 - mae: 4.5985
# Epoch 419/500
# 62/62 [==============================] - 2s 39ms/step - loss: 4.1288 - mae: 4.5979
# Epoch 420/500
# 62/62 [==============================] - 3s 53ms/step - loss: 4.1283 - mae: 4.5974
# Epoch 421/500
# 62/62 [==============================] - 3s 50ms/step - loss: 4.1278 - mae: 4.5968
# Epoch 422/500
# 62/62 [==============================] - 3s 41ms/step - loss: 4.1272 - mae: 4.5962
# Epoch 423/500
# 62/62 [==============================] - 3s 47ms/step - loss: 4.1267 - mae: 4.5957
# Epoch 424/500
# 62/62 [==============================] - 3s 44ms/step - loss: 4.1261 - mae: 4.5950
# Epoch 425/500
# 62/62 [==============================] - 2s 38ms/step - loss: 4.1256 - mae: 4.5945
# Epoch 426/500
# 62/62 [==============================] - 2s 40ms/step - loss: 4.1250 - mae: 4.5939
# Epoch 427/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.1245 - mae: 4.5933
# Epoch 428/500
# 62/62 [==============================] - 2s 36ms/step - loss: 4.1239 - mae: 4.5927
# Epoch 429/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.1234 - mae: 4.5922
# Epoch 430/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.1229 - mae: 4.5916
# Epoch 431/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.1223 - mae: 4.5910
# Epoch 432/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.1218 - mae: 4.5904
# Epoch 433/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.1212 - mae: 4.5899
# Epoch 434/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.1207 - mae: 4.5893
# Epoch 435/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.1201 - mae: 4.5887
# Epoch 436/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.1196 - mae: 4.5881
# Epoch 437/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.1191 - mae: 4.5876
# Epoch 438/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.1185 - mae: 4.5870
# Epoch 439/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.1180 - mae: 4.5865
# Epoch 440/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.1174 - mae: 4.5858
# Epoch 441/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.1169 - mae: 4.5853
# Epoch 442/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.1164 - mae: 4.5847
# Epoch 443/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.1159 - mae: 4.5842
# Epoch 444/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.1154 - mae: 4.5836
# Epoch 445/500
# 62/62 [==============================] - 2s 36ms/step - loss: 4.1148 - mae: 4.5831
# Epoch 446/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.1143 - mae: 4.5825
# Epoch 447/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.1137 - mae: 4.5819
# Epoch 448/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.1132 - mae: 4.5814
# Epoch 449/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.1127 - mae: 4.5808
# Epoch 450/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.1122 - mae: 4.5802
# Epoch 451/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.1116 - mae: 4.5797
# Epoch 452/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.1111 - mae: 4.5791
# Epoch 453/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.1106 - mae: 4.5785
# Epoch 454/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.1101 - mae: 4.5780
# Epoch 455/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.1095 - mae: 4.5775
# Epoch 456/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.1091 - mae: 4.5770
# Epoch 457/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.1085 - mae: 4.5764
# Epoch 458/500
# 62/62 [==============================] - 2s 33ms/step - loss: 4.1080 - mae: 4.5758
# Epoch 459/500
# 62/62 [==============================] - 3s 48ms/step - loss: 4.1075 - mae: 4.5753
# Epoch 460/500
# 62/62 [==============================] - 3s 52ms/step - loss: 4.1069 - mae: 4.5747
# Epoch 461/500
# 62/62 [==============================] - 5s 81ms/step - loss: 4.1064 - mae: 4.5742
# Epoch 462/500
# 62/62 [==============================] - 5s 87ms/step - loss: 4.1059 - mae: 4.5737
# Epoch 463/500
# 62/62 [==============================] - 5s 79ms/step - loss: 4.1053 - mae: 4.5732
# Epoch 464/500
# 62/62 [==============================] - 5s 77ms/step - loss: 4.1049 - mae: 4.5727
# Epoch 465/500
# 62/62 [==============================] - 4s 64ms/step - loss: 4.1043 - mae: 4.5722
# Epoch 466/500
# 62/62 [==============================] - 2s 38ms/step - loss: 4.1039 - mae: 4.5718
# Epoch 467/500
# 62/62 [==============================] - 2s 36ms/step - loss: 4.1033 - mae: 4.5713
# Epoch 468/500
# 62/62 [==============================] - 5s 73ms/step - loss: 4.1029 - mae: 4.5708
# Epoch 469/500
# 62/62 [==============================] - 5s 81ms/step - loss: 4.1024 - mae: 4.5703
# Epoch 470/500
# 62/62 [==============================] - 4s 64ms/step - loss: 4.1019 - mae: 4.5699
# Epoch 471/500
# 62/62 [==============================] - 4s 64ms/step - loss: 4.1015 - mae: 4.5694
# Epoch 472/500
# 62/62 [==============================] - 3s 50ms/step - loss: 4.1010 - mae: 4.5690
# Epoch 473/500
# 62/62 [==============================] - 4s 66ms/step - loss: 4.1006 - mae: 4.5685
# Epoch 474/500
# 62/62 [==============================] - 4s 59ms/step - loss: 4.1001 - mae: 4.5680
# Epoch 475/500
# 62/62 [==============================] - 4s 64ms/step - loss: 4.0997 - mae: 4.5676
# Epoch 476/500
# 62/62 [==============================] - 3s 43ms/step - loss: 4.0992 - mae: 4.5671
# Epoch 477/500
# 62/62 [==============================] - 3s 41ms/step - loss: 4.0987 - mae: 4.5667
# Epoch 478/500
# 62/62 [==============================] - 3s 51ms/step - loss: 4.0983 - mae: 4.5662
# Epoch 479/500
# 62/62 [==============================] - 5s 74ms/step - loss: 4.0978 - mae: 4.5658
# Epoch 480/500
# 62/62 [==============================] - 4s 64ms/step - loss: 4.0974 - mae: 4.5653
# Epoch 481/500
# 62/62 [==============================] - 6s 93ms/step - loss: 4.0969 - mae: 4.5649
# Epoch 482/500
# 62/62 [==============================] - 5s 81ms/step - loss: 4.0965 - mae: 4.5644
# Epoch 483/500
# 62/62 [==============================] - 5s 73ms/step - loss: 4.0960 - mae: 4.5640
# Epoch 484/500
# 62/62 [==============================] - 4s 58ms/step - loss: 4.0956 - mae: 4.5636
# Epoch 485/500
# 62/62 [==============================] - 4s 70ms/step - loss: 4.0952 - mae: 4.5632
# Epoch 486/500
# 62/62 [==============================] - 5s 73ms/step - loss: 4.0947 - mae: 4.5626
# Epoch 487/500
# 62/62 [==============================] - 5s 73ms/step - loss: 4.0942 - mae: 4.5622
# Epoch 488/500
# 62/62 [==============================] - 4s 71ms/step - loss: 4.0938 - mae: 4.5618
# Epoch 489/500
# 62/62 [==============================] - 4s 64ms/step - loss: 4.0934 - mae: 4.5613
# Epoch 490/500
# 62/62 [==============================] - 4s 68ms/step - loss: 4.0929 - mae: 4.5609
# Epoch 491/500
# 62/62 [==============================] - 4s 68ms/step - loss: 4.0924 - mae: 4.5604
# Epoch 492/500
# 62/62 [==============================] - 5s 74ms/step - loss: 4.0919 - mae: 4.5599
# Epoch 493/500
# 62/62 [==============================] - 4s 67ms/step - loss: 4.0915 - mae: 4.5595
# Epoch 494/500
# 62/62 [==============================] - 4s 68ms/step - loss: 4.0910 - mae: 4.5590
# Epoch 495/500
# 62/62 [==============================] - 4s 69ms/step - loss: 4.0906 - mae: 4.5586
# Epoch 496/500
# 62/62 [==============================] - 5s 77ms/step - loss: 4.0902 - mae: 4.5582
# Epoch 497/500
# 62/62 [==============================] - 5s 74ms/step - loss: 4.0897 - mae: 4.5577
# Epoch 498/500
# 62/62 [==============================] - 4s 60ms/step - loss: 4.0892 - mae: 4.5572
# Epoch 499/500
# 62/62 [==============================] - 5s 73ms/step - loss: 4.0888 - mae: 4.5568
# Epoch 500/500
# 62/62 [==============================] - 5s 75ms/step - loss: 4.0883 - mae: 4.5563

# %% [markdown]
# Training can be a bit unstable especially as the weights start to converge so you may want to visualize it to see if it is still trending down. The earlier epochs might dominate the graph so it's also good to zoom in on the later parts of training to properly observe the parameters. The code below visualizes the `mae` and `loss` for all epochs, and also zooms in at the last 80%.

# %%
# Get mae and loss from history log
mae=history.history['mae']
loss=history.history['loss']

# Get number of epochs
epochs=range(len(loss)) 

# Plot mae and loss
plot_series(
    x=epochs, 
    y=(mae, loss), 
    title='MAE and Loss', 
    xlabel='Epochs',
    legend=['MAE', 'Loss']
    )

# Only plot the last 80% of the epochs
zoom_split = int(epochs[-1] * 0.2)
epochs_zoom = epochs[zoom_split:]
mae_zoom = mae[zoom_split:]
loss_zoom = loss[zoom_split:]

# Plot zoomed mae and loss
plot_series(
    x=epochs_zoom, 
    y=(mae_zoom, loss_zoom), 
    title='MAE and Loss', 
    xlabel='Epochs',
    legend=['MAE', 'Loss']
    )

# %% [markdown]
# ## Model Prediction
#
# Once training is done, you can generate the model predictions and plot them against the validation set.

# %%
def model_forecast(model, series, window_size, batch_size):
    """Uses an input model to generate predictions on data windows

    Args:
      model (TF Keras Model) - model that accepts data windows
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the window
      batch_size (int) - the batch size

    Returns:
      forecast (numpy array) - array containing predictions
    """

    # Add an axis for the feature dimension of RNN layers
    series = tf.expand_dims(series, axis=-1)
    
    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda w: w.batch(window_size))
    
    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)
    
    # Get predictions on the entire dataset
    forecast = model.predict(dataset, verbose=0)
    
    return forecast

# %%
# Reduce the original series
forecast_series = series[split_time-window_size:-1]

# Use helper function to generate predictions
forecast = model_forecast(model, forecast_series, window_size, batch_size)

# Drop single dimensional axes
results = forecast.squeeze()

# Plot the results
plot_series(time_valid, (x_valid, results))
# Out:
# 2025-02-26 11:25:14.137818: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [480,1]
# 	 [[{{node Placeholder/_0}}]]
# 2025-02-26 11:25:14.138391: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [480,1]
# 	 [[{{node Placeholder/_0}}]]
# 2025-02-26 11:25:14.763392: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 11:25:14.767284: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 11:25:14.772103: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 11:25:15.340796: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 11:25:15.347127: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 11:25:15.350377: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %% [markdown]
# You can then compute the metrics as usual.

# %%
## Compute the MAE and MSE
print(tf.keras.metrics.mse(x_valid, results).numpy())
print(tf.keras.metrics.mae(x_valid, results).numpy())
# Out:
# 56.373493
# 5.569331

# %% [markdown]
# ## Wrap Up
#
# In this lab, you were able to build and train a CNN-RNN model for forecasting. This concludes the series of notebooks on training with synthetic data. In the next labs, you will be looking at a real world time series dataset, particularly sunspot cycles. See you there!
#
# If you won't explore the optional exercises below, please uncomment the cell below and run it to free up resources for the next labs.

# %%
# # Uncomment the code below if you will not explore the optional section.
# # Shutdown the kernel to free up resources. 
# # Note: You can expect a pop-up when you run this cell. You can safely ignore that and just press `Ok`.

# from IPython import get_ipython

# k = get_ipython().kernel

# k.do_shutdown(restart=False)

# %% [markdown]
# ## Optional - Adding a Callback for Early Stopping
#
# In this optional section, you will add a callback to stop training when a metric is met. You already did this in the first course of this specialization and now would be a good time to review.

# %% [markdown]
# First, you need to prepare a validation set that the model can use and monitor. As shown in the previous lab, you can use the `windowed_dataset()` function to prepare this.

# %%
# Generate data windows from the validation set
val_set = windowed_dataset(x_valid, window_size, batch_size, shuffle_buffer_size)

# %% [markdown]
# You can reset the weights of the model or just continue from where you left off.

# %%
# Uncomment if you want to reset the weights
# model.set_weights(init_weights)

# %% [markdown]
# Next, you will define a callback function that is run every end of an epoch. Inside, you will define the condition to stop training. For this lab, you will set it to stop when the `val_mae` is less than `5.7`.

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    '''
    Halts the training when a certain metric is met

    Args:
      epoch (integer) - index of epoch (required but unused in the function
                        definition below)
      logs (dict) - metric results from the training epoch
    '''

    # Check the validation set MAE
    if(logs.get('val_mae') < 5.7):

      # Stop if threshold is met
      print("\nRequired val MAE is met so cancelling training!")
      self.model.stop_training = True

# Instantiate the class
callbacks = myCallback()

# %% [markdown]
# Remember to set an appropriate learning rate here. If you're starting from random weights, you may want to use the same rate you used earlier. If you did not reset the weights however, you can use a lower learning rate so the model can learn better. If all goes well, the training will stop before the set 500 epochs are completed.

# %%
# Set the learning rate
learning_rate = 4e-8

# Set the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# Train the model
history = model.fit(train_set, epochs=500,
                    validation_data=val_set, callbacks=[callbacks])
# Out:
# Epoch 1/500
# 2025-02-26 11:29:28.907182: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 11:29:28.910285: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 11:29:28.912954: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 11:29:29.223231: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 11:29:29.228576: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 11:29:29.231548: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 11:29:30.658243: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 11:29:30.663988: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 11:29:30.667460: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 11:29:31.040445: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 11:29:31.046031: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 11:29:31.049546: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
#      61/Unknown - 7s 36ms/step - loss: 4.0153 - mae: 4.4864
# 2025-02-26 11:29:35.805491: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [461,1]
# 	 [[{{node Placeholder/_0}}]]
# 2025-02-26 11:29:35.806279: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [461,1]
# 	 [[{{node Placeholder/_0}}]]
# 2025-02-26 11:29:36.335833: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 11:29:36.340037: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 11:29:36.344756: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 11:29:36.822558: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 11:29:36.824776: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 11:29:36.829078: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Required val MAE is met so cancelling training!
# 62/62 [==============================] - 9s 70ms/step - loss: 4.0235 - mae: 4.4947 - val_loss: 5.2095 - val_mae: 5.6887

# %% [markdown]
# In practice, you normally have a separate test set to evaluate against unseen data. For this exercise however, the dataset is already very small so let's just use the same validation set just to verify that the results are comparable to the one you got earlier.

# %%
# Reduce the original series
forecast_series = series[split_time-window_size:-1]

# Use helper function to generate predictions
forecast = model_forecast(model, forecast_series, window_size, batch_size)

# Drop single dimensional axis
results = forecast.squeeze()

# Plot the results
plot_series(time_valid, (x_valid, results))
# Out:
# 2025-02-26 11:29:48.805533: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [480,1]
# 	 [[{{node Placeholder/_0}}]]
# 2025-02-26 11:29:48.806348: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [480,1]
# 	 [[{{node Placeholder/_0}}]]
# 2025-02-26 11:29:49.237548: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 11:29:49.239797: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 11:29:49.243300: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 11:29:49.566613: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 11:29:49.568756: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 11:29:49.570312: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %% [markdown]
# The computed metrics here will be slightly different from the one shown in the training output because it has more points to evaluate. Remember that `x_valid` has 461 points that corresponds to `t=1000` to `t=1460`. `val_set` (which is a windowed dataset from `x_valid`), on the other hand, only has 441 points because it cannot generate predictions for `t=1000` to `t=1019` (i.e. windowing will start there).

# %%
## Compute the MAE and MSE
print(tf.keras.metrics.mse(x_valid, results).numpy())
print(tf.keras.metrics.mae(x_valid, results).numpy())
# Out:
# 57.196495
# 5.6106777

# %% [markdown]
# Run the cell below to free up resources for the next lab.

# %%
# Note: You can expect a pop-up when you run this cell. You can safely ignore that and just press `Ok`.

# from IPython import get_ipython

# k = get_ipython().kernel

# k.do_shutdown(restart=False)
