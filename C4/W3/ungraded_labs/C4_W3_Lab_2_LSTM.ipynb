# %% [markdown]
# # Ungraded Lab: Using a multi-layer LSTM for forecasting
#
# In this lab, you will use the same RNN architecure in the first lab but will instead stack [LSTM](https://www.tensorflow.org/api_docs/python/tf/keras/layers/LSTM) layers instead of `SimpleRNN`.

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2025-02-26 09:13:09.548981: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-02-26 09:13:09.632627: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-02-26 09:13:09.634802: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-26 09:13:11.672564: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Utilities

# %%
def plot_series(time, series, format="-", start=0, end=None):
    """
    Visualizes time series data

    Args:
      time (array of int) - contains the time steps
      series (array of int) - contains the measurements for each time step
      format - line style when plotting the graph
      start - first time step to plot
      end - last time step to plot
    """

    # Setup dimensions of the graph figure
    plt.figure(figsize=(10, 6))
    
    if type(series) is tuple:

      for series_num in series:
        # Plot the time series data
        plt.plot(time[start:end], series_num[start:end], format)

    else:
      # Plot the time series data
      plt.plot(time[start:end], series[start:end], format)

    # Label the x-axis
    plt.xlabel("Time")

    # Label the y-axis
    plt.ylabel("Value")

    # Overlay a grid on the graph
    plt.grid(True)

    # Draw the graph on screen
    plt.show()

def trend(time, slope=0):
    """
    Generates synthetic data that follows a straight line given a slope value.

    Args:
      time (array of int) - contains the time steps
      slope (float) - determines the direction and steepness of the line

    Returns:
      series (array of float) - measurements that follow a straight line
    """

    # Compute the linear series given the slope
    series = slope * time

    return series

def seasonal_pattern(season_time):
    """
    Just an arbitrary pattern, you can change it if you wish
    
    Args:
      season_time (array of float) - contains the measurements per time step

    Returns:
      data_pattern (array of float) -  contains revised measurement values according 
                                  to the defined pattern
    """

    # Generate the values using an arbitrary pattern
    data_pattern = np.where(season_time < 0.4,
                    np.cos(season_time * 2 * np.pi),
                    1 / np.exp(3 * season_time))
    
    return data_pattern

def seasonality(time, period, amplitude=1, phase=0):
    """
    Repeats the same pattern at each period

    Args:
      time (array of int) - contains the time steps
      period (int) - number of time steps before the pattern repeats
      amplitude (int) - peak measured value in a period
      phase (int) - number of time steps to shift the measured values

    Returns:
      data_pattern (array of float) - seasonal data scaled by the defined amplitude
    """
    
    # Define the measured values per period
    season_time = ((time + phase) % period) / period

    # Generates the seasonal data scaled by the defined amplitude
    data_pattern = amplitude * seasonal_pattern(season_time)

    return data_pattern

def noise(time, noise_level=1, seed=None):
    """Generates a normally distributed noisy signal

    Args:
      time (array of int) - contains the time steps
      noise_level (float) - scaling factor for the generated signal
      seed (int) - number generator seed for repeatability

    Returns:
      noise (array of float) - the noisy signal
    """

    # Initialize the random number generator
    rnd = np.random.RandomState(seed)

    # Generate a random number for each time step and scale by the noise level
    noise = rnd.randn(len(time)) * noise_level
    
    return noise

# %% [markdown]
# ## Generate the Synthetic Data

# %%
# Parameters
time = np.arange(4 * 365 + 1, dtype="float32")
baseline = 10
amplitude = 40
slope = 0.05
noise_level = 5

# Create the series
series = baseline + trend(time, slope) + \
    seasonality(time, period=365, amplitude=amplitude)

# Update with noise
series += noise(time, noise_level, seed=42)

# Plot the results
plot_series(time, series)

# %% [markdown]
# ## Split the Dataset

# %%
# Define the split time
split_time = 1000

# Get the train set 
time_train = time[:split_time]
x_train = series[:split_time]

# Get the validation set
time_valid = time[split_time:]
x_valid = series[split_time:]

# %% [markdown]
# ## Prepare Features and Labels

# %%
# Parameters
window_size = 20
batch_size = 32
shuffle_buffer_size = 1000

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer,
                     labels_size=1):
    """Generates dataset windows

    Args:
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the feature
      batch_size (int) - the batch size
      shuffle_buffer(int) - buffer size to use for the shuffle method

    Returns:
      dataset (TF Dataset) - TF Dataset containing time windows
    """

    # Add an axis for the feature dimension of RNN layers
    series = tf.expand_dims(series, axis=-1) # NOTICE aditional axis!

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)
    
    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)
    
    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))

    # Create tuples with features and labels 
    dataset = dataset.map(lambda window: (window[:-labels_size],
                                          window[-labels_size]))

    # Shuffle the windows
    dataset = dataset.shuffle(shuffle_buffer)
    
    # Create batches of windows
    dataset = dataset.batch(batch_size)
    
    # Optimize the dataset for training
    dataset = dataset.cache().prefetch(1)
    
    return dataset

# %%
# Generate the dataset windows
dataset = windowed_dataset(x_train, window_size, batch_size,
                           shuffle_buffer_size)

# %% [markdown]
# ## Build the Model
#
# As mentioned, you will swap `SimpleRNN` for `LSTM` in this lab. It is also set as bidirectional below but feel free to revise later and see what results you get. LSTMs are much more complex in their internal architecture than simpleRNNs. It implements a cell state that allows it to remember sequences better than simple implementations. This added complexity results in a bigger set of parameters to train and you'll see that when you print the model summary below.

# %%
# Build the Model
model_tune = tf.keras.models.Sequential([
    tf.keras.Input(shape=(window_size, 1)),
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(32, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(1),
    tf.keras.layers.Lambda(lambda x: x * 100.0)
])

# Print the model summary
model_tune.summary()
# Out:
# 2025-02-26 09:22:40.764422: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:22:40.769072: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:22:40.771227: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:22:40.971413: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:22:41.035967: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:22:41.037486: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:22:41.039034: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:22:41.266226: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:22:41.269391: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:22:41.270807: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:22:41.425756: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (None, 20, 64)           8704
#  nal)
#
#  bidirectional_3 (Bidirectio  (None, 64)               24832
#  nal)
#
#  dense_1 (Dense)             (None, 1)                 65
#
#  lambda_1 (Lambda)           (None, 1)                 0
#
# =================================================================
# Total params: 33,601
# Trainable params: 33,601
# Non-trainable params: 0
# _________________________________________________________________
# 2025-02-26 09:22:41.481147: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:22:41.482501: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:22:41.484209: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %% [markdown]
# ## Tune the Learning Rate
#
# As usual, you will pick a learning rate by running the tuning code below.

# %%
# Set the learning rate scheduler
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))

# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD(momentum=0.9)

# Set the training parameters
model_tune.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer)

# Train the model
history = model_tune.fit(dataset, epochs=100, callbacks=[lr_schedule])
# Out:
# Epoch 1/100
# 2025-02-26 09:22:58.281119: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [1000,1]
# 	 [[{{node Placeholder/_0}}]]
# 2025-02-26 09:22:58.281618: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [1000,1]
# 	 [[{{node Placeholder/_0}}]]
# 2025-02-26 09:22:58.623585: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:22:58.625559: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:22:58.627118: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:22:58.779157: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:22:58.835980: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:22:58.838437: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:22:58.840549: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:22:59.134565: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:22:59.140559: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:22:59.144762: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:22:59.523859: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:22:59.578926: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:22:59.580226: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:22:59.581373: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:23:00.270441: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:23:01.072116: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:23:01.469402: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:23:01.471541: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:23:01.473091: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:23:01.646813: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:23:01.714733: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:23:01.718378: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:23:01.720535: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:23:01.965728: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:23:01.969503: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:23:01.971569: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:23:02.145370: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:23:02.213929: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:23:02.215660: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:23:02.218597: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:23:02.882783: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:23:03.860673: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 31/31 [==============================] - 9s 44ms/step - loss: 20.3671 - lr: 1.0000e-08
# Epoch 2/100
# 31/31 [==============================] - 1s 31ms/step - loss: 20.1533 - lr: 1.1220e-08
# Epoch 3/100
# 31/31 [==============================] - 1s 33ms/step - loss: 19.9106 - lr: 1.2589e-08
# Epoch 4/100
# 31/31 [==============================] - 1s 28ms/step - loss: 19.6589 - lr: 1.4125e-08
# Epoch 5/100
# 31/31 [==============================] - 1s 25ms/step - loss: 19.4007 - lr: 1.5849e-08
# Epoch 6/100
# 31/31 [==============================] - 1s 23ms/step - loss: 19.1352 - lr: 1.7783e-08
# Epoch 7/100
# 31/31 [==============================] - 1s 22ms/step - loss: 18.8654 - lr: 1.9953e-08
# Epoch 8/100
# 31/31 [==============================] - 1s 21ms/step - loss: 18.5928 - lr: 2.2387e-08
# Epoch 9/100
# 31/31 [==============================] - 1s 21ms/step - loss: 18.3159 - lr: 2.5119e-08
# Epoch 10/100
# 31/31 [==============================] - 1s 21ms/step - loss: 18.0364 - lr: 2.8184e-08
# Epoch 11/100
# 31/31 [==============================] - 1s 21ms/step - loss: 17.7625 - lr: 3.1623e-08
# Epoch 12/100
# 31/31 [==============================] - 1s 21ms/step - loss: 17.5004 - lr: 3.5481e-08
# Epoch 13/100
# 31/31 [==============================] - 1s 30ms/step - loss: 17.2493 - lr: 3.9811e-08
# Epoch 14/100
# 31/31 [==============================] - 1s 38ms/step - loss: 17.0036 - lr: 4.4668e-08
# Epoch 15/100
# 31/31 [==============================] - 1s 41ms/step - loss: 16.7534 - lr: 5.0119e-08
# Epoch 16/100
# 31/31 [==============================] - 1s 27ms/step - loss: 16.4848 - lr: 5.6234e-08
# Epoch 17/100
# 31/31 [==============================] - 1s 27ms/step - loss: 16.1738 - lr: 6.3096e-08
# Epoch 18/100
# 31/31 [==============================] - 1s 29ms/step - loss: 15.7889 - lr: 7.0795e-08
# Epoch 19/100
# 31/31 [==============================] - 1s 23ms/step - loss: 15.3010 - lr: 7.9433e-08
# Epoch 20/100
# 31/31 [==============================] - 1s 30ms/step - loss: 14.7245 - lr: 8.9125e-08
# Epoch 21/100
# 31/31 [==============================] - 1s 25ms/step - loss: 14.1316 - lr: 1.0000e-07
# Epoch 22/100
# 31/31 [==============================] - 1s 26ms/step - loss: 13.5630 - lr: 1.1220e-07
# Epoch 23/100
# 31/31 [==============================] - 1s 28ms/step - loss: 12.9972 - lr: 1.2589e-07
# Epoch 24/100
# 31/31 [==============================] - 1s 27ms/step - loss: 12.4021 - lr: 1.4125e-07
# Epoch 25/100
# 31/31 [==============================] - 1s 24ms/step - loss: 11.7736 - lr: 1.5849e-07
# Epoch 26/100
# 31/31 [==============================] - 1s 23ms/step - loss: 11.1290 - lr: 1.7783e-07
# Epoch 27/100
# 31/31 [==============================] - 1s 25ms/step - loss: 10.4799 - lr: 1.9953e-07
# Epoch 28/100
# 31/31 [==============================] - 1s 29ms/step - loss: 9.8390 - lr: 2.2387e-07
# Epoch 29/100
# 31/31 [==============================] - 1s 24ms/step - loss: 9.2407 - lr: 2.5119e-07
# Epoch 30/100
# 31/31 [==============================] - 1s 22ms/step - loss: 8.6929 - lr: 2.8184e-07
# Epoch 31/100
# 31/31 [==============================] - 1s 23ms/step - loss: 8.1978 - lr: 3.1623e-07
# Epoch 32/100
# 31/31 [==============================] - 1s 22ms/step - loss: 7.8062 - lr: 3.5481e-07
# Epoch 33/100
# 31/31 [==============================] - 1s 24ms/step - loss: 7.5419 - lr: 3.9811e-07
# Epoch 34/100
# 31/31 [==============================] - 1s 21ms/step - loss: 7.3728 - lr: 4.4668e-07
# Epoch 35/100
# 31/31 [==============================] - 1s 21ms/step - loss: 7.2548 - lr: 5.0119e-07
# Epoch 36/100
# 31/31 [==============================] - 1s 21ms/step - loss: 7.1646 - lr: 5.6234e-07
# Epoch 37/100
# 31/31 [==============================] - 1s 22ms/step - loss: 7.0938 - lr: 6.3096e-07
# Epoch 38/100
# 31/31 [==============================] - 1s 24ms/step - loss: 7.0311 - lr: 7.0795e-07
# Epoch 39/100
# 31/31 [==============================] - 1s 21ms/step - loss: 6.9720 - lr: 7.9433e-07
# Epoch 40/100
# 31/31 [==============================] - 1s 22ms/step - loss: 6.9116 - lr: 8.9125e-07
# Epoch 41/100
# 31/31 [==============================] - 1s 24ms/step - loss: 6.8459 - lr: 1.0000e-06
# Epoch 42/100
# 31/31 [==============================] - 1s 30ms/step - loss: 6.7804 - lr: 1.1220e-06
# Epoch 43/100
# 31/31 [==============================] - 1s 23ms/step - loss: 6.7130 - lr: 1.2589e-06
# Epoch 44/100
# 31/31 [==============================] - 1s 22ms/step - loss: 6.6439 - lr: 1.4125e-06
# Epoch 45/100
# 31/31 [==============================] - 1s 23ms/step - loss: 6.5718 - lr: 1.5849e-06
# Epoch 46/100
# 31/31 [==============================] - 1s 23ms/step - loss: 6.4956 - lr: 1.7783e-06
# Epoch 47/100
# 31/31 [==============================] - 1s 27ms/step - loss: 6.4186 - lr: 1.9953e-06
# Epoch 48/100
# 31/31 [==============================] - 1s 24ms/step - loss: 6.3490 - lr: 2.2387e-06
# Epoch 49/100
# 31/31 [==============================] - 1s 24ms/step - loss: 6.2897 - lr: 2.5119e-06
# Epoch 50/100
# 31/31 [==============================] - 1s 23ms/step - loss: 6.2434 - lr: 2.8184e-06
# Epoch 51/100
# 31/31 [==============================] - 1s 27ms/step - loss: 6.2034 - lr: 3.1623e-06
# Epoch 52/100
# 31/31 [==============================] - 1s 25ms/step - loss: 6.1841 - lr: 3.5481e-06
# Epoch 53/100
# 31/31 [==============================] - 1s 24ms/step - loss: 6.1961 - lr: 3.9811e-06
# Epoch 54/100
# 31/31 [==============================] - 1s 24ms/step - loss: 6.2895 - lr: 4.4668e-06
# Epoch 55/100
# 31/31 [==============================] - 1s 28ms/step - loss: 6.4251 - lr: 5.0119e-06
# Epoch 56/100
# 31/31 [==============================] - 1s 22ms/step - loss: 6.5575 - lr: 5.6234e-06
# Epoch 57/100
# 31/31 [==============================] - 1s 22ms/step - loss: 6.6722 - lr: 6.3096e-06
# Epoch 58/100
# 31/31 [==============================] - 1s 22ms/step - loss: 6.7289 - lr: 7.0795e-06
# Epoch 59/100
# 31/31 [==============================] - 1s 22ms/step - loss: 6.8689 - lr: 7.9433e-06
# Epoch 60/100
# 31/31 [==============================] - 1s 29ms/step - loss: 6.9898 - lr: 8.9125e-06
# Epoch 61/100
# 31/31 [==============================] - 1s 22ms/step - loss: 7.1534 - lr: 1.0000e-05
# Epoch 62/100
# 31/31 [==============================] - 1s 22ms/step - loss: 7.3345 - lr: 1.1220e-05
# Epoch 63/100
# 31/31 [==============================] - 1s 22ms/step - loss: 7.4026 - lr: 1.2589e-05
# Epoch 64/100
# 31/31 [==============================] - 1s 24ms/step - loss: 7.8198 - lr: 1.4125e-05
# Epoch 65/100
# 31/31 [==============================] - 1s 22ms/step - loss: 7.5545 - lr: 1.5849e-05
# Epoch 66/100
# 31/31 [==============================] - 1s 22ms/step - loss: 6.0025 - lr: 1.7783e-05
# Epoch 67/100
# 31/31 [==============================] - 1s 22ms/step - loss: 6.5235 - lr: 1.9953e-05
# Epoch 68/100
# 31/31 [==============================] - 1s 24ms/step - loss: 6.1210 - lr: 2.2387e-05
# Epoch 69/100
# 31/31 [==============================] - 1s 27ms/step - loss: 7.7011 - lr: 2.5119e-05
# Epoch 70/100
# 31/31 [==============================] - 1s 23ms/step - loss: 5.4134 - lr: 2.8184e-05
# Epoch 71/100
# 31/31 [==============================] - 1s 22ms/step - loss: 5.3571 - lr: 3.1623e-05
# Epoch 72/100
# 31/31 [==============================] - 1s 24ms/step - loss: 5.7454 - lr: 3.5481e-05
# Epoch 73/100
# 31/31 [==============================] - 1s 26ms/step - loss: 6.0254 - lr: 3.9811e-05
# Epoch 74/100
# 31/31 [==============================] - 1s 23ms/step - loss: 6.1532 - lr: 4.4668e-05
# Epoch 75/100
# 31/31 [==============================] - 1s 24ms/step - loss: 6.2604 - lr: 5.0119e-05
# Epoch 76/100
# 31/31 [==============================] - 1s 24ms/step - loss: 7.1167 - lr: 5.6234e-05
# Epoch 77/100
# 31/31 [==============================] - 1s 28ms/step - loss: 6.7878 - lr: 6.3096e-05
# Epoch 78/100
# 31/31 [==============================] - 1s 24ms/step - loss: 7.3679 - lr: 7.0795e-05
# Epoch 79/100
# 31/31 [==============================] - 1s 24ms/step - loss: 7.5718 - lr: 7.9433e-05
# Epoch 80/100
# 31/31 [==============================] - 1s 24ms/step - loss: 7.3916 - lr: 8.9125e-05
# Epoch 81/100
# 31/31 [==============================] - 1s 30ms/step - loss: 7.5957 - lr: 1.0000e-04
# Epoch 82/100
# 31/31 [==============================] - 1s 24ms/step - loss: 9.0407 - lr: 1.1220e-04
# Epoch 83/100
# 31/31 [==============================] - 1s 24ms/step - loss: 8.3760 - lr: 1.2589e-04
# Epoch 84/100
# 31/31 [==============================] - 1s 22ms/step - loss: 7.7693 - lr: 1.4125e-04
# Epoch 85/100
# 31/31 [==============================] - 1s 24ms/step - loss: 6.9078 - lr: 1.5849e-04
# Epoch 86/100
# 31/31 [==============================] - 1s 22ms/step - loss: 7.5730 - lr: 1.7783e-04
# Epoch 87/100
# 31/31 [==============================] - 1s 22ms/step - loss: 5.8302 - lr: 1.9953e-04
# Epoch 88/100
# 31/31 [==============================] - 1s 22ms/step - loss: 10.4223 - lr: 2.2387e-04
# Epoch 89/100
# 31/31 [==============================] - 1s 24ms/step - loss: 8.3254 - lr: 2.5119e-04
# Epoch 90/100
# 31/31 [==============================] - 1s 21ms/step - loss: 7.4236 - lr: 2.8184e-04
# Epoch 91/100
# 31/31 [==============================] - 1s 22ms/step - loss: 6.6970 - lr: 3.1623e-04
# Epoch 92/100
# 31/31 [==============================] - 1s 21ms/step - loss: 7.7685 - lr: 3.5481e-04
# Epoch 93/100
# 31/31 [==============================] - 1s 24ms/step - loss: 8.1822 - lr: 3.9811e-04
# Epoch 94/100
# 31/31 [==============================] - 1s 22ms/step - loss: 10.8523 - lr: 4.4668e-04
# Epoch 95/100
# 31/31 [==============================] - 1s 22ms/step - loss: 8.4788 - lr: 5.0119e-04
# Epoch 96/100
# 31/31 [==============================] - 1s 23ms/step - loss: 9.5682 - lr: 5.6234e-04
# Epoch 97/100
# 31/31 [==============================] - 1s 23ms/step - loss: 11.4029 - lr: 6.3096e-04
# Epoch 98/100
# 31/31 [==============================] - 1s 24ms/step - loss: 12.6019 - lr: 7.0795e-04
# Epoch 99/100
# 31/31 [==============================] - 1s 24ms/step - loss: 13.2618 - lr: 7.9433e-04
# Epoch 100/100
# 31/31 [==============================] - 1s 23ms/step - loss: 17.3642 - lr: 8.9125e-04

# %%
# Define the learning rate array
lrs = 1e-8 * (10 ** (np.arange(100) / 20))

# Set the figure size
plt.figure(figsize=(10, 6))

# Set the grid
plt.grid(True)

# Plot the loss in log scale
plt.semilogx(lrs, history.history["loss"])

# Increase the tickmarks size
plt.tick_params('both', length=10, width=1, which='both')

# Set the plot boundaries
plt.axis([1e-8, 1e-3, 0, 30])
plt.xlabel("Learning Rate")
plt.ylabel("Loss")
plt.axvline(2e-6, color='r');

# %% [markdown]
# ## Train the Model
#
# You can then proceed to train the model with your chosen learning rate.
#
# *Tip: When experimenting and you find yourself running different iterations of a model, you may want to use the [`clear_session()`](https://www.tensorflow.org/api_docs/python/tf/keras/backend/clear_session) method to declutter memory used by Keras. This is added in the first line below.*

# %%
# Reset states generated by Keras
tf.keras.backend.clear_session()

# Build the model
model = tf.keras.models.Sequential([
    tf.keras.Input(shape=(window_size, 1)),
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(32, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(1),
    tf.keras.layers.Lambda(lambda x: x * 100.0)
])

# Set the learning rate
learning_rate = 2e-6

# Set the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# Train the model
history = model.fit(dataset, epochs=100)
# Out:
# 2025-02-26 09:32:37.503346: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:32:37.505249: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:32:37.506362: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:32:37.657899: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:32:37.715554: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:32:37.717993: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:32:37.723142: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:32:38.107064: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:32:38.109316: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:32:38.110900: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:32:38.294134: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# Epoch 1/100
# 2025-02-26 09:32:38.378418: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:32:38.382659: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:32:38.386409: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:32:38.824591: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:32:38.826929: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:32:38.828827: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:32:39.092802: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:32:39.187872: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:32:39.189982: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:32:39.191780: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:32:39.497904: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:32:39.500880: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:32:39.502877: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:32:39.691950: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:32:39.781636: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:32:39.785312: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:32:39.787148: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:32:40.455045: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:32:41.092132: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:32:41.520723: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:32:41.522683: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:32:41.524005: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:32:41.722890: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:32:41.797622: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:32:41.800150: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:32:41.802355: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:32:42.472168: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:32:42.473850: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:32:42.475209: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:32:42.656340: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:32:42.731744: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:32:42.734605: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:32:42.736382: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:32:43.403290: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:32:43.975830: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 31/31 [==============================] - 8s 23ms/step - loss: 40.6284 - mae: 41.1249
# Epoch 2/100
# 31/31 [==============================] - 1s 22ms/step - loss: 9.8542 - mae: 10.3388
# Epoch 3/100
# 31/31 [==============================] - 1s 24ms/step - loss: 7.6766 - mae: 8.1603
# Epoch 4/100
# 31/31 [==============================] - 1s 26ms/step - loss: 6.9438 - mae: 7.4251
# Epoch 5/100
# 31/31 [==============================] - 1s 24ms/step - loss: 6.5249 - mae: 7.0044
# Epoch 6/100
# 31/31 [==============================] - 1s 23ms/step - loss: 6.2622 - mae: 6.7420
# Epoch 7/100
# 31/31 [==============================] - 1s 25ms/step - loss: 6.0622 - mae: 6.5413
# Epoch 8/100
# 31/31 [==============================] - 1s 26ms/step - loss: 5.9012 - mae: 6.3800
# Epoch 9/100
# 31/31 [==============================] - 1s 27ms/step - loss: 5.7683 - mae: 6.2477
# Epoch 10/100
# 31/31 [==============================] - 1s 28ms/step - loss: 5.6570 - mae: 6.1356
# Epoch 11/100
# 31/31 [==============================] - 1s 35ms/step - loss: 5.5719 - mae: 6.0516
# Epoch 12/100
# 31/31 [==============================] - 1s 23ms/step - loss: 5.5134 - mae: 5.9940
# Epoch 13/100
# 31/31 [==============================] - 1s 22ms/step - loss: 5.4718 - mae: 5.9522
# Epoch 14/100
# 31/31 [==============================] - 1s 23ms/step - loss: 5.4427 - mae: 5.9225
# Epoch 15/100
# 31/31 [==============================] - 1s 24ms/step - loss: 5.4146 - mae: 5.8938
# Epoch 16/100
# 31/31 [==============================] - 1s 26ms/step - loss: 5.3857 - mae: 5.8644
# Epoch 17/100
# 31/31 [==============================] - 1s 21ms/step - loss: 5.3583 - mae: 5.8361
# Epoch 18/100
# 31/31 [==============================] - 1s 21ms/step - loss: 5.3333 - mae: 5.8106
# Epoch 19/100
# 31/31 [==============================] - 1s 20ms/step - loss: 5.3101 - mae: 5.7876
# Epoch 20/100
# 31/31 [==============================] - 1s 21ms/step - loss: 5.2885 - mae: 5.7659
# Epoch 21/100
# 31/31 [==============================] - 1s 23ms/step - loss: 5.2673 - mae: 5.7451
# Epoch 22/100
# 31/31 [==============================] - 1s 21ms/step - loss: 5.2461 - mae: 5.7241
# Epoch 23/100
# 31/31 [==============================] - 1s 20ms/step - loss: 5.2263 - mae: 5.7043
# Epoch 24/100
# 31/31 [==============================] - 1s 21ms/step - loss: 5.2084 - mae: 5.6862
# Epoch 25/100
# 31/31 [==============================] - 1s 20ms/step - loss: 5.1909 - mae: 5.6681
# Epoch 26/100
# 31/31 [==============================] - 1s 23ms/step - loss: 5.1742 - mae: 5.6508
# Epoch 27/100
# 31/31 [==============================] - 1s 20ms/step - loss: 5.1587 - mae: 5.6347
# Epoch 28/100
# 31/31 [==============================] - 1s 21ms/step - loss: 5.1445 - mae: 5.6199
# Epoch 29/100
# 31/31 [==============================] - 1s 21ms/step - loss: 5.1313 - mae: 5.6064
# Epoch 30/100
# 31/31 [==============================] - 1s 27ms/step - loss: 5.1186 - mae: 5.5937
# Epoch 31/100
# 31/31 [==============================] - 1s 22ms/step - loss: 5.1064 - mae: 5.5813
# Epoch 32/100
# 31/31 [==============================] - 1s 22ms/step - loss: 5.0944 - mae: 5.5694
# Epoch 33/100
# 31/31 [==============================] - 1s 21ms/step - loss: 5.0826 - mae: 5.5578
# Epoch 34/100
# 31/31 [==============================] - 1s 21ms/step - loss: 5.0712 - mae: 5.5464
# Epoch 35/100
# 31/31 [==============================] - 1s 23ms/step - loss: 5.0604 - mae: 5.5357
# Epoch 36/100
# 31/31 [==============================] - 1s 20ms/step - loss: 5.0500 - mae: 5.5255
# Epoch 37/100
# 31/31 [==============================] - 1s 21ms/step - loss: 5.0401 - mae: 5.5157
# Epoch 38/100
# 31/31 [==============================] - 1s 21ms/step - loss: 5.0306 - mae: 5.5065
# Epoch 39/100
# 31/31 [==============================] - 1s 22ms/step - loss: 5.0218 - mae: 5.4981
# Epoch 40/100
# 31/31 [==============================] - 1s 24ms/step - loss: 5.0134 - mae: 5.4900
# Epoch 41/100
# 31/31 [==============================] - 1s 21ms/step - loss: 5.0054 - mae: 5.4822
# Epoch 42/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.9978 - mae: 5.4750
# Epoch 43/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.9903 - mae: 5.4680
# Epoch 44/100
# 31/31 [==============================] - 1s 22ms/step - loss: 4.9830 - mae: 5.4611
# Epoch 45/100
# 31/31 [==============================] - 1s 23ms/step - loss: 4.9754 - mae: 5.4538
# Epoch 46/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.9679 - mae: 5.4465
# Epoch 47/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.9608 - mae: 5.4395
# Epoch 48/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.9539 - mae: 5.4328
# Epoch 49/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.9471 - mae: 5.4261
# Epoch 50/100
# 31/31 [==============================] - 1s 24ms/step - loss: 4.9405 - mae: 5.4197
# Epoch 51/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.9344 - mae: 5.4136
# Epoch 52/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.9285 - mae: 5.4079
# Epoch 53/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.9227 - mae: 5.4022
# Epoch 54/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.9170 - mae: 5.3965
# Epoch 55/100
# 31/31 [==============================] - 1s 22ms/step - loss: 4.9110 - mae: 5.3906
# Epoch 56/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.9049 - mae: 5.3846
# Epoch 57/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.8987 - mae: 5.3784
# Epoch 58/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.8925 - mae: 5.3722
# Epoch 59/100
# 31/31 [==============================] - 1s 26ms/step - loss: 4.8862 - mae: 5.3658
# Epoch 60/100
# 31/31 [==============================] - 1s 22ms/step - loss: 4.8799 - mae: 5.3593
# Epoch 61/100
# 31/31 [==============================] - 1s 22ms/step - loss: 4.8737 - mae: 5.3530
# Epoch 62/100
# 31/31 [==============================] - 1s 22ms/step - loss: 4.8676 - mae: 5.3466
# Epoch 63/100
# 31/31 [==============================] - 1s 23ms/step - loss: 4.8615 - mae: 5.3404
# Epoch 64/100
# 31/31 [==============================] - 1s 24ms/step - loss: 4.8554 - mae: 5.3342
# Epoch 65/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.8493 - mae: 5.3279
# Epoch 66/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.8432 - mae: 5.3217
# Epoch 67/100
# 31/31 [==============================] - 1s 23ms/step - loss: 4.8373 - mae: 5.3157
# Epoch 68/100
# 31/31 [==============================] - 1s 26ms/step - loss: 4.8315 - mae: 5.3098
# Epoch 69/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.8259 - mae: 5.3040
# Epoch 70/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.8202 - mae: 5.2982
# Epoch 71/100
# 31/31 [==============================] - 1s 22ms/step - loss: 4.8145 - mae: 5.2924
# Epoch 72/100
# 31/31 [==============================] - 1s 23ms/step - loss: 4.8094 - mae: 5.2874
# Epoch 73/100
# 31/31 [==============================] - 1s 24ms/step - loss: 4.8046 - mae: 5.2825
# Epoch 74/100
# 31/31 [==============================] - 1s 22ms/step - loss: 4.7997 - mae: 5.2775
# Epoch 75/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.7947 - mae: 5.2726
# Epoch 76/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.7899 - mae: 5.2677
# Epoch 77/100
# 31/31 [==============================] - 1s 23ms/step - loss: 4.7852 - mae: 5.2629
# Epoch 78/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.7808 - mae: 5.2583
# Epoch 79/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.7764 - mae: 5.2539
# Epoch 80/100
# 31/31 [==============================] - 1s 22ms/step - loss: 4.7721 - mae: 5.2496
# Epoch 81/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.7679 - mae: 5.2453
# Epoch 82/100
# 31/31 [==============================] - 1s 23ms/step - loss: 4.7638 - mae: 5.2412
# Epoch 83/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.7599 - mae: 5.2372
# Epoch 84/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.7561 - mae: 5.2334
# Epoch 85/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.7523 - mae: 5.2297
# Epoch 86/100
# 31/31 [==============================] - 1s 22ms/step - loss: 4.7485 - mae: 5.2261
# Epoch 87/100
# 31/31 [==============================] - 1s 23ms/step - loss: 4.7448 - mae: 5.2225
# Epoch 88/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.7411 - mae: 5.2189
# Epoch 89/100
# 31/31 [==============================] - 1s 23ms/step - loss: 4.7375 - mae: 5.2153
# Epoch 90/100
# 31/31 [==============================] - 1s 24ms/step - loss: 4.7339 - mae: 5.2118
# Epoch 91/100
# 31/31 [==============================] - 1s 29ms/step - loss: 4.7304 - mae: 5.2083
# Epoch 92/100
# 31/31 [==============================] - 1s 27ms/step - loss: 4.7270 - mae: 5.2049
# Epoch 93/100
# 31/31 [==============================] - 1s 28ms/step - loss: 4.7237 - mae: 5.2016
# Epoch 94/100
# 31/31 [==============================] - 1s 25ms/step - loss: 4.7204 - mae: 5.1983
# Epoch 95/100
# 31/31 [==============================] - 1s 25ms/step - loss: 4.7172 - mae: 5.1950
# Epoch 96/100
# 31/31 [==============================] - 1s 27ms/step - loss: 4.7140 - mae: 5.1917
# Epoch 97/100
# 31/31 [==============================] - 1s 26ms/step - loss: 4.7108 - mae: 5.1885
# Epoch 98/100
# 31/31 [==============================] - 1s 25ms/step - loss: 4.7078 - mae: 5.1855
# Epoch 99/100
# 31/31 [==============================] - 1s 24ms/step - loss: 4.7047 - mae: 5.1824
# Epoch 100/100
# 31/31 [==============================] - 1s 27ms/step - loss: 4.7017 - mae: 5.1794

# %% [markdown]
# ## Model Prediction
#
# You will then generate batches of windows to generate predictions that align with the validation set.

# %%
def model_forecast(model, series, window_size, batch_size):
    """Uses an input model to generate predictions on data windows

    Args:
      model (TF Keras Model) - model that accepts data windows
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the window
      batch_size (int) - the batch size

    Returns:
      forecast (numpy array) - array containing predictions
    """

    # Add an axis for the feature dimension of RNN layers
    series = tf.expand_dims(series, axis=-1)
    
    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda w: w.batch(window_size))
    
    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)
    
    # Get predictions on the entire dataset
    forecast = model.predict(dataset, verbose=0)
    
    return forecast

# %%
# Reduce the original series
forecast_series = series[split_time-window_size:-1]

# Use helper function to generate predictions
forecast = model_forecast(model, forecast_series, window_size, batch_size)

# Drop single dimensional axis
results = forecast.squeeze()

# Plot the results
plot_series(time_valid, (x_valid, results))
# Out:
# 2025-02-26 09:34:15.669014: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [480,1]
# 	 [[{{node Placeholder/_0}}]]
# 2025-02-26 09:34:15.669782: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [480,1]
# 	 [[{{node Placeholder/_0}}]]
# 2025-02-26 09:34:15.996230: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:34:15.997737: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:34:16.000200: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:34:16.159163: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:34:16.228105: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:34:16.230175: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:34:16.232387: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:34:16.540405: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:34:16.542560: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:34:16.544022: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:34:16.798784: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:34:16.895345: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:34:16.899193: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:34:16.902420: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %% [markdown]
# You can then generate the metrics to evaluate the model's performance.

# %%
# Compute the MSE and MAE
print(tf.keras.metrics.mse(x_valid, results).numpy())
print(tf.keras.metrics.mae(x_valid, results).numpy())
# Out:
# 70.2079
# 5.8393826

# %% [markdown]
# ## Wrap Up
#
# This concludes this short exercise on using LSTMs for time series forecasting. Next week, you will build upon this and add convolutions. Then, you will start to move away from synthetic data and use real-world datasets. See you there!

# %% [markdown]
# ## Optional: Including a Validation Set while Training
#
# Back in the first course of this specialization, you saw how you can also monitor the performance of your model against a validation set while training. You can also do that for this lab.
#
# First, you need to generate a `val_set` which are data windows and labels that your model can accept. You can simply reuse the `windowed_dataset` function for that and you can pass in the `x_valid` points to generate the windows.

# %%
# Generate data windows of the validation set
val_set = windowed_dataset(
    x_valid, window_size, batch_size, shuffle_buffer_size)

# %% [markdown]
# You can then do the same training as before but pass in the `val_set` to the `validation_data` parameter of the `fit()` method.

# %%
# Reset states generated by Keras
tf.keras.backend.clear_session()

# Build the model
model = tf.keras.models.Sequential([
    tf.keras.Input(shape=(window_size, 1)),
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(32, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(1),
    tf.keras.layers.Lambda(lambda x: x * 100.0)
])

# Set the learning rate
learning_rate = 2e-6

# Set the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# Train the model with the validation set
history = model.fit(dataset, epochs=100, validation_data=val_set)
# Out:
# 2025-02-26 09:36:27.487144: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:36:27.489210: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:36:27.490823: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:36:27.638939: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:36:27.690198: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:36:27.693325: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:36:27.694682: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:36:27.978477: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:36:27.981063: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:36:27.982621: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:36:28.152777: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# Epoch 1/100
# 2025-02-26 09:36:28.214584: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:36:28.217484: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:36:28.220287: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:36:28.663072: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:36:28.665893: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:36:28.668533: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:36:28.913676: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:36:28.989681: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:36:28.991755: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:36:28.993663: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:36:29.254887: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:36:29.257292: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:36:29.258723: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:36:29.438432: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:36:29.522421: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:36:29.525470: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:36:29.527096: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:36:30.183652: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:36:30.726759: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:36:31.148082: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:36:31.150342: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:36:31.153078: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:36:31.328157: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:36:31.399605: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:36:31.402742: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:36:31.405388: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:36:31.664475: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:36:31.666230: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:36:31.667412: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:36:31.859878: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:36:31.931772: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:36:31.933433: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:36:31.934727: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:36:33.024173: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:36:33.584364: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
#      30/Unknown - 8s 26ms/step - loss: 23.5551 - mae: 24.0502
# 2025-02-26 09:36:36.301923: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [461,1]
# 	 [[{{node Placeholder/_0}}]]
# 2025-02-26 09:36:36.302532: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [461,1]
# 	 [[{{node Placeholder/_0}}]]
# 2025-02-26 09:36:36.682522: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:36:36.685184: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:36:36.688839: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:36:36.941427: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:36:37.023813: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:36:37.025522: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:36:37.027126: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:36:37.316401: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:36:37.317693: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:36:37.321008: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:36:37.530070: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:36:37.612662: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:36:37.614141: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:36:37.615380: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 31/31 [==============================] - 10s 93ms/step - loss: 23.3136 - mae: 23.8089 - val_loss: 23.2069 - val_mae: 23.7041
# Epoch 2/100
# 31/31 [==============================] - 1s 28ms/step - loss: 8.9150 - mae: 9.4022 - val_loss: 18.6063 - val_mae: 19.1015
# Epoch 3/100
# 31/31 [==============================] - 1s 36ms/step - loss: 6.2820 - mae: 6.7644 - val_loss: 13.8156 - val_mae: 14.3095
# Epoch 4/100
# 31/31 [==============================] - 1s 35ms/step - loss: 5.8285 - mae: 6.3086 - val_loss: 11.6399 - val_mae: 12.1281
# Epoch 5/100
# 31/31 [==============================] - 1s 36ms/step - loss: 5.5530 - mae: 6.0333 - val_loss: 10.6487 - val_mae: 11.1396
# Epoch 6/100
# 31/31 [==============================] - 1s 30ms/step - loss: 5.3792 - mae: 5.8620 - val_loss: 9.9288 - val_mae: 10.4204
# Epoch 7/100
# 31/31 [==============================] - 1s 29ms/step - loss: 5.2547 - mae: 5.7349 - val_loss: 9.4320 - val_mae: 9.9218
# Epoch 8/100
# 31/31 [==============================] - 1s 26ms/step - loss: 5.1499 - mae: 5.6294 - val_loss: 8.9407 - val_mae: 9.4312
# Epoch 9/100
# 31/31 [==============================] - 1s 30ms/step - loss: 5.0475 - mae: 5.5265 - val_loss: 8.4603 - val_mae: 8.9507
# Epoch 10/100
# 31/31 [==============================] - 1s 30ms/step - loss: 4.9463 - mae: 5.4233 - val_loss: 8.0279 - val_mae: 8.5185
# Epoch 11/100
# 31/31 [==============================] - 1s 27ms/step - loss: 4.8588 - mae: 5.3354 - val_loss: 7.6845 - val_mae: 8.1716
# Epoch 12/100
# 31/31 [==============================] - 1s 25ms/step - loss: 4.7976 - mae: 5.2752 - val_loss: 7.4136 - val_mae: 7.8964
# Epoch 13/100
# 31/31 [==============================] - 1s 34ms/step - loss: 4.7504 - mae: 5.2290 - val_loss: 7.1872 - val_mae: 7.6670
# Epoch 14/100
# 31/31 [==============================] - 1s 29ms/step - loss: 4.7140 - mae: 5.1925 - val_loss: 6.9983 - val_mae: 7.4789
# Epoch 15/100
# 31/31 [==============================] - 1s 31ms/step - loss: 4.6860 - mae: 5.1663 - val_loss: 6.8337 - val_mae: 7.3144
# Epoch 16/100
# 31/31 [==============================] - 1s 33ms/step - loss: 4.6637 - mae: 5.1450 - val_loss: 6.6906 - val_mae: 7.1717
# Epoch 17/100
# 31/31 [==============================] - 1s 29ms/step - loss: 4.6445 - mae: 5.1266 - val_loss: 6.5620 - val_mae: 7.0461
# Epoch 18/100
# 31/31 [==============================] - 1s 25ms/step - loss: 4.6270 - mae: 5.1096 - val_loss: 6.4599 - val_mae: 6.9458
# Epoch 19/100
# 31/31 [==============================] - 1s 34ms/step - loss: 4.6117 - mae: 5.0940 - val_loss: 6.3721 - val_mae: 6.8582
# Epoch 20/100
# 31/31 [==============================] - 1s 26ms/step - loss: 4.5979 - mae: 5.0797 - val_loss: 6.2984 - val_mae: 6.7840
# Epoch 21/100
# 31/31 [==============================] - 1s 25ms/step - loss: 4.5861 - mae: 5.0675 - val_loss: 6.2323 - val_mae: 6.7173
# Epoch 22/100
# 31/31 [==============================] - 1s 25ms/step - loss: 4.5762 - mae: 5.0568 - val_loss: 6.1709 - val_mae: 6.6547
# Epoch 23/100
# 31/31 [==============================] - 1s 25ms/step - loss: 4.5675 - mae: 5.0473 - val_loss: 6.1147 - val_mae: 6.5975
# Epoch 24/100
# 31/31 [==============================] - 1s 28ms/step - loss: 4.5595 - mae: 5.0385 - val_loss: 6.0585 - val_mae: 6.5403
# Epoch 25/100
# 31/31 [==============================] - 1s 26ms/step - loss: 4.5520 - mae: 5.0310 - val_loss: 6.0074 - val_mae: 6.4884
# Epoch 26/100
# 31/31 [==============================] - 1s 26ms/step - loss: 4.5449 - mae: 5.0237 - val_loss: 5.9619 - val_mae: 6.4432
# Epoch 27/100
# 31/31 [==============================] - 1s 26ms/step - loss: 4.5382 - mae: 5.0169 - val_loss: 5.9187 - val_mae: 6.4007
# Epoch 28/100
# 31/31 [==============================] - 1s 27ms/step - loss: 4.5320 - mae: 5.0105 - val_loss: 5.8804 - val_mae: 6.3630
# Epoch 29/100
# 31/31 [==============================] - 1s 24ms/step - loss: 4.5261 - mae: 5.0045 - val_loss: 5.8470 - val_mae: 6.3300
# Epoch 30/100
# 31/31 [==============================] - 1s 26ms/step - loss: 4.5202 - mae: 4.9985 - val_loss: 5.8157 - val_mae: 6.2988
# Epoch 31/100
# 31/31 [==============================] - 1s 25ms/step - loss: 4.5146 - mae: 4.9928 - val_loss: 5.7856 - val_mae: 6.2685
# Epoch 32/100
# 31/31 [==============================] - 1s 27ms/step - loss: 4.5091 - mae: 4.9872 - val_loss: 5.7567 - val_mae: 6.2394
# Epoch 33/100
# 31/31 [==============================] - 1s 32ms/step - loss: 4.5038 - mae: 4.9817 - val_loss: 5.7291 - val_mae: 6.2118
# Epoch 34/100
# 31/31 [==============================] - 1s 36ms/step - loss: 4.4985 - mae: 4.9763 - val_loss: 5.7024 - val_mae: 6.1851
# Epoch 35/100
# 31/31 [==============================] - 1s 28ms/step - loss: 4.4934 - mae: 4.9711 - val_loss: 5.6755 - val_mae: 6.1583
# Epoch 36/100
# 31/31 [==============================] - 1s 25ms/step - loss: 4.4885 - mae: 4.9659 - val_loss: 5.6483 - val_mae: 6.1316
# Epoch 37/100
# 31/31 [==============================] - 1s 31ms/step - loss: 4.4837 - mae: 4.9608 - val_loss: 5.6231 - val_mae: 6.1065
# Epoch 38/100
# 31/31 [==============================] - 1s 27ms/step - loss: 4.4790 - mae: 4.9560 - val_loss: 5.5982 - val_mae: 6.0819
# Epoch 39/100
# 31/31 [==============================] - 1s 25ms/step - loss: 4.4743 - mae: 4.9515 - val_loss: 5.5735 - val_mae: 6.0571
# Epoch 40/100
# 31/31 [==============================] - 1s 28ms/step - loss: 4.4698 - mae: 4.9470 - val_loss: 5.5490 - val_mae: 6.0332
# Epoch 41/100
# 31/31 [==============================] - 1s 30ms/step - loss: 4.4653 - mae: 4.9426 - val_loss: 5.5247 - val_mae: 6.0095
# Epoch 42/100
# 31/31 [==============================] - 1s 31ms/step - loss: 4.4611 - mae: 4.9385 - val_loss: 5.4999 - val_mae: 5.9858
# Epoch 43/100
# 31/31 [==============================] - 1s 27ms/step - loss: 4.4570 - mae: 4.9343 - val_loss: 5.4743 - val_mae: 5.9610
# Epoch 44/100
# 31/31 [==============================] - 1s 34ms/step - loss: 4.4527 - mae: 4.9300 - val_loss: 5.4480 - val_mae: 5.9351
# Epoch 45/100
# 31/31 [==============================] - 1s 28ms/step - loss: 4.4487 - mae: 4.9260 - val_loss: 5.4208 - val_mae: 5.9081
# Epoch 46/100
# 31/31 [==============================] - 1s 33ms/step - loss: 4.4450 - mae: 4.9223 - val_loss: 5.3926 - val_mae: 5.8799
# Epoch 47/100
# 31/31 [==============================] - 1s 29ms/step - loss: 4.4414 - mae: 4.9188 - val_loss: 5.3613 - val_mae: 5.8483
# Epoch 48/100
# 31/31 [==============================] - 1s 30ms/step - loss: 4.4379 - mae: 4.9155 - val_loss: 5.3295 - val_mae: 5.8157
# Epoch 49/100
# 31/31 [==============================] - 1s 29ms/step - loss: 4.4345 - mae: 4.9124 - val_loss: 5.2971 - val_mae: 5.7821
# Epoch 50/100
# 31/31 [==============================] - 1s 32ms/step - loss: 4.4310 - mae: 4.9092 - val_loss: 5.2651 - val_mae: 5.7485
# Epoch 51/100
# 31/31 [==============================] - 1s 36ms/step - loss: 4.4271 - mae: 4.9055 - val_loss: 5.2341 - val_mae: 5.7168
# Epoch 52/100
# 31/31 [==============================] - 2s 61ms/step - loss: 4.4222 - mae: 4.9008 - val_loss: 5.2057 - val_mae: 5.6886
# Epoch 53/100
# 31/31 [==============================] - 2s 51ms/step - loss: 4.4185 - mae: 4.8970 - val_loss: 5.1776 - val_mae: 5.6599
# Epoch 54/100
# 31/31 [==============================] - 1s 42ms/step - loss: 4.4155 - mae: 4.8939 - val_loss: 5.1540 - val_mae: 5.6357
# Epoch 55/100
# 31/31 [==============================] - 1s 40ms/step - loss: 4.4130 - mae: 4.8913 - val_loss: 5.1338 - val_mae: 5.6148
# Epoch 56/100
# 31/31 [==============================] - 1s 38ms/step - loss: 4.4107 - mae: 4.8889 - val_loss: 5.1165 - val_mae: 5.5974
# Epoch 57/100
# 31/31 [==============================] - 1s 43ms/step - loss: 4.4086 - mae: 4.8866 - val_loss: 5.1016 - val_mae: 5.5821
# Epoch 58/100
# 31/31 [==============================] - 1s 46ms/step - loss: 4.4067 - mae: 4.8845 - val_loss: 5.0895 - val_mae: 5.5697
# Epoch 59/100
# 31/31 [==============================] - 1s 30ms/step - loss: 4.4048 - mae: 4.8825 - val_loss: 5.0789 - val_mae: 5.5591
# Epoch 60/100
# 31/31 [==============================] - 1s 30ms/step - loss: 4.4031 - mae: 4.8806 - val_loss: 5.0698 - val_mae: 5.5498
# Epoch 61/100
# 31/31 [==============================] - 1s 31ms/step - loss: 4.4014 - mae: 4.8788 - val_loss: 5.0619 - val_mae: 5.5417
# Epoch 62/100
# 31/31 [==============================] - 1s 27ms/step - loss: 4.3998 - mae: 4.8771 - val_loss: 5.0546 - val_mae: 5.5343
# Epoch 63/100
# 31/31 [==============================] - 1s 27ms/step - loss: 4.3982 - mae: 4.8754 - val_loss: 5.0483 - val_mae: 5.5279
# Epoch 64/100
# 31/31 [==============================] - 1s 27ms/step - loss: 4.3966 - mae: 4.8738 - val_loss: 5.0428 - val_mae: 5.5223
# Epoch 65/100
# 31/31 [==============================] - 1s 32ms/step - loss: 4.3951 - mae: 4.8723 - val_loss: 5.0381 - val_mae: 5.5176
# Epoch 66/100
# 31/31 [==============================] - 1s 27ms/step - loss: 4.3936 - mae: 4.8708 - val_loss: 5.0340 - val_mae: 5.5134
# Epoch 67/100
# 31/31 [==============================] - 1s 30ms/step - loss: 4.3921 - mae: 4.8693 - val_loss: 5.0302 - val_mae: 5.5095
# Epoch 68/100
# 31/31 [==============================] - 1s 35ms/step - loss: 4.3907 - mae: 4.8678 - val_loss: 5.0266 - val_mae: 5.5058
# Epoch 69/100
# 31/31 [==============================] - 1s 29ms/step - loss: 4.3893 - mae: 4.8664 - val_loss: 5.0230 - val_mae: 5.5021
# Epoch 70/100
# 31/31 [==============================] - 1s 25ms/step - loss: 4.3879 - mae: 4.8650 - val_loss: 5.0197 - val_mae: 5.4988
# Epoch 71/100
# 31/31 [==============================] - 1s 24ms/step - loss: 4.3865 - mae: 4.8636 - val_loss: 5.0167 - val_mae: 5.4957
# Epoch 72/100
# 31/31 [==============================] - 1s 24ms/step - loss: 4.3852 - mae: 4.8623 - val_loss: 5.0137 - val_mae: 5.4926
# Epoch 73/100
# 31/31 [==============================] - 1s 27ms/step - loss: 4.3838 - mae: 4.8610 - val_loss: 5.0108 - val_mae: 5.4896
# Epoch 74/100
# 31/31 [==============================] - 1s 24ms/step - loss: 4.3825 - mae: 4.8597 - val_loss: 5.0081 - val_mae: 5.4868
# Epoch 75/100
# 31/31 [==============================] - 1s 23ms/step - loss: 4.3812 - mae: 4.8585 - val_loss: 5.0053 - val_mae: 5.4840
# Epoch 76/100
# 31/31 [==============================] - 1s 24ms/step - loss: 4.3800 - mae: 4.8572 - val_loss: 5.0027 - val_mae: 5.4812
# Epoch 77/100
# 31/31 [==============================] - 1s 28ms/step - loss: 4.3787 - mae: 4.8560 - val_loss: 4.9999 - val_mae: 5.4783
# Epoch 78/100
# 31/31 [==============================] - 1s 25ms/step - loss: 4.3775 - mae: 4.8548 - val_loss: 4.9972 - val_mae: 5.4755
# Epoch 79/100
# 31/31 [==============================] - 1s 28ms/step - loss: 4.3763 - mae: 4.8536 - val_loss: 4.9946 - val_mae: 5.4728
# Epoch 80/100
# 31/31 [==============================] - 1s 26ms/step - loss: 4.3751 - mae: 4.8525 - val_loss: 4.9920 - val_mae: 5.4702
# Epoch 81/100
# 31/31 [==============================] - 1s 30ms/step - loss: 4.3739 - mae: 4.8513 - val_loss: 4.9896 - val_mae: 5.4676
# Epoch 82/100
# 31/31 [==============================] - 1s 26ms/step - loss: 4.3727 - mae: 4.8502 - val_loss: 4.9872 - val_mae: 5.4652
# Epoch 83/100
# 31/31 [==============================] - 1s 26ms/step - loss: 4.3715 - mae: 4.8491 - val_loss: 4.9850 - val_mae: 5.4629
# Epoch 84/100
# 31/31 [==============================] - 1s 26ms/step - loss: 4.3704 - mae: 4.8479 - val_loss: 4.9829 - val_mae: 5.4607
# Epoch 85/100
# 31/31 [==============================] - 1s 29ms/step - loss: 4.3692 - mae: 4.8468 - val_loss: 4.9808 - val_mae: 5.4586
# Epoch 86/100
# 31/31 [==============================] - 1s 26ms/step - loss: 4.3681 - mae: 4.8457 - val_loss: 4.9787 - val_mae: 5.4565
# Epoch 87/100
# 31/31 [==============================] - 1s 25ms/step - loss: 4.3670 - mae: 4.8446 - val_loss: 4.9766 - val_mae: 5.4543
# Epoch 88/100
# 31/31 [==============================] - 1s 26ms/step - loss: 4.3660 - mae: 4.8436 - val_loss: 4.9744 - val_mae: 5.4521
# Epoch 89/100
# 31/31 [==============================] - 1s 28ms/step - loss: 4.3649 - mae: 4.8425 - val_loss: 4.9724 - val_mae: 5.4500
# Epoch 90/100
# 31/31 [==============================] - 1s 25ms/step - loss: 4.3638 - mae: 4.8415 - val_loss: 4.9704 - val_mae: 5.4479
# Epoch 91/100
# 31/31 [==============================] - 1s 25ms/step - loss: 4.3628 - mae: 4.8404 - val_loss: 4.9684 - val_mae: 5.4458
# Epoch 92/100
# 31/31 [==============================] - 1s 25ms/step - loss: 4.3617 - mae: 4.8394 - val_loss: 4.9662 - val_mae: 5.4436
# Epoch 93/100
# 31/31 [==============================] - 1s 31ms/step - loss: 4.3607 - mae: 4.8384 - val_loss: 4.9641 - val_mae: 5.4414
# Epoch 94/100
# 31/31 [==============================] - 1s 31ms/step - loss: 4.3597 - mae: 4.8373 - val_loss: 4.9620 - val_mae: 5.4392
# Epoch 95/100
# 31/31 [==============================] - 1s 31ms/step - loss: 4.3587 - mae: 4.8363 - val_loss: 4.9599 - val_mae: 5.4370
# Epoch 96/100
# 31/31 [==============================] - 1s 32ms/step - loss: 4.3576 - mae: 4.8353 - val_loss: 4.9579 - val_mae: 5.4349
# Epoch 97/100
# 31/31 [==============================] - 1s 31ms/step - loss: 4.3566 - mae: 4.8343 - val_loss: 4.9559 - val_mae: 5.4329
# Epoch 98/100
# 31/31 [==============================] - 1s 29ms/step - loss: 4.3556 - mae: 4.8333 - val_loss: 4.9540 - val_mae: 5.4310
# Epoch 99/100
# 31/31 [==============================] - 1s 24ms/step - loss: 4.3547 - mae: 4.8322 - val_loss: 4.9521 - val_mae: 5.4290
# Epoch 100/100
# 31/31 [==============================] - 1s 27ms/step - loss: 4.3537 - mae: 4.8313 - val_loss: 4.9502 - val_mae: 5.4271

# %%
# Reduce the original series
forecast_series = series[split_time-window_size:-1]

# Use helper function to generate predictions
forecast = model_forecast(model, forecast_series, window_size, batch_size)

# Drop single dimensional axis
results = forecast.squeeze()


print(tf.keras.metrics.mse(x_valid, results).numpy())
print(tf.keras.metrics.mae(x_valid, results).numpy())

# Plot the results
plot_series(time_valid, (x_valid, results))
# Out:
# 2025-02-26 09:39:13.508939: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [480,1]
# 	 [[{{node Placeholder/_0}}]]
# 2025-02-26 09:39:13.509629: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [480,1]
# 	 [[{{node Placeholder/_0}}]]
# 2025-02-26 09:39:13.776393: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:39:13.778746: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:39:13.780725: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:39:13.959574: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:39:14.032457: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:39:14.035345: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:39:14.037757: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:39:14.289277: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:39:14.291892: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:39:14.293516: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-02-26 09:39:14.466884: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-02-26 09:39:14.542787: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-02-26 09:39:14.544903: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-02-26 09:39:14.546452: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 56.773857
# 5.3604503
